# %%
import pandas as pd
import numpy as np
import codecs
import re
import os
from datetime import datetime

# %% [markdown]
# ### Goal
# - Transform the system log into dataframe
# - Each row record all activities happened within 1 second
# - User actions include watch (default action), path replaning (add way point, set goal), apply automation, engage payload
#     - Apply automation is an one-shot action, user apply the system suggestion and the action finished immediately.
#
# - Description of coding
#     - vehicle status
#         - 1: moving
#         - 2: arrived target
#         - 3: engage payload
#
# - 2022/12/14 add two new attributes: collision and VHcollision, which are indicators to label is there existing collisions.

# %% [markdown]
# ### Set source directory, target file and keys

# %%
root_dir = "/Users/chanhsu/Projects/HRI/uav_hsmm/HMM_Experiment/RAW_DATA/TK/HRB_TK_HW/"
csv_file = "/Users/chanhsu/Projects/HRI/uav_hsmm/uav_hsmm/data/data_20221107/TK/TK_HRB_HW.csv"

os.listdir(root_dir)
# Out:
# ['HRB15_TK_HW.txt_fixed',
#  'HRB20_TK_HW.txt_fixed',
#  'HRB3_TK_HW.txt_fixed',
#  'HRB12_TK_HW.txt_fixed',
#  'HRB2_TK_HW.txt_fixed',
#  'HRB21_TK_HW.txt_fixed',
#  'HRB13_TK_HW.txt_fixed',
#  'HRB14_TK_HW.txt_fixed',
#  'HRB11_TK_HW.txt_fixed',
#  'HRB8_TK_HW.txt_fixed',
#  'HRB7_TK_HW.txt_fixed',
#  'HRB9_TK_HW.txt_fixed',
#  'desktop.ini',
#  'HRB6_TK_HW.txt_fixed',
#  'HRB1_TK_HW.txt_fixed',
#  'HRB10_TK_HW.txt_fixed']

# %%
keys = (
    "file_name", "event_id", "time", 
    "action", "payload_act", "n_correct", "n_incorrect",
    "collision", "VHcollision", "is_damaged",
    "v1_x", "v1_y", "v2_x", "v2_y", "v3_x", "v3_y", "v4_x", "v4_y", "v5_x", "v5_y",
    "v1_target", "v2_target", "v3_target", "v4_target", "v5_target", 
    "v1_status", "v2_status", "v3_status", "v4_status", "v5_status", 
    "ta_x", "ta_y", "tb_x", "tb_y", "tc_x", "tc_y", "td_x", "td_y", "te_x", "te_y", "tf_x", "tf_y", "tg_x", "tg_y",
    "h1_x", "h1_y", "h2_x", "h2_y", "h3_x", "h3_y", "h4_x", "h4_y", "h5_x", "h5_y", 
    "h6_x", "h6_y", "h7_x", "h7_y", "h8_x", "h8_y", "h9_x", "h9_y", "h10_x", "h10_y",
)

# %%
event_list = list()

# %% [markdown]
# ### Extract contents from log files

# %%
for file_name in os.listdir(root_dir):
    
    if file_name == "desktop.ini": 
        ## ignore system file
        continue

    ## Initialize values
    event_num = 0
    num_correct = 0
    num_incorrect = 0
    action = None


    ## Load file content
    file_path = root_dir + file_name
    file = codecs.open(file_path, 'r', encoding='utf-8')
    lines  = file.readlines()
    print(f"""file name: {file_path}""")

    ## remove first line from list (experiment start)
    lines.pop(0)

    new_event = dict(zip(keys, [None] * len(keys)))

    ## Start to transform
    for i in range(len(lines)):
    # for i in range(200):

        # print("start transformation")
        # initialize row
        if i == 0:
            new_event = dict(zip(keys, [None] * len(keys)))
    
        ## debug message
        # if i % 10000 == 0:
        #     print(f"""line: {i}, content: {lines[i]}""")

        ## Extract User action
        # if event_num == 0:
        #     new_event.update({"action": "watch"})
        
        """Update user's behavior""" 
        ## aggregate WP add, WP move and WP delete as one class
        if re.search('WP add start', lines[i]) is not None or re.search('WP move start', lines[i]) is not None or re.search('WP delete start', lines[i]) is not None or re.search('Goal set start', lines[i]) is not None:
            new_event.update({"action": "replanPath" })
            continue

        ## add a temporary action "end" to calculate duration
        elif re.search('WP add end', lines[i]) is not None or re.search('WP move end', lines[i]) is not None or re.search('WP add canceled', lines[i]) is not None or re.search('Goal change end', lines[i]) is not None:
            new_event.update({"action": "end" })
            continue

        elif re.search('Payload Finished', lines[i]) is not None:
            new_event.update({"action": "end" })
        
        elif re.search('Payload Engaged', lines[i]) is not None:
            new_event.update({"action": "engagePayload" })
            continue
        
        elif re.search('User applies automation', lines[i]) is not None:
            new_event.update({"action": "applyAutomation" })
            continue
        
        """Update damage"""
        if re.search('Damaged with a HazardArea', lines[i]) is not None:
            new_event.update({'is_damaged': 1}) ## Indicator
            continue

        """Update indicators of collsions"""
        ## if current line includes "Collisions" and next line includes the detail of collision.
        if re.search('Collisions', lines[i]) is not None and re.search('Area', lines[i+1]) is not None:
            new_event.update({"collision": 1})
            continue

        if re.search('VH Collision', lines[i]) is not None and len(lines[i]) >= 5:
            new_event.update({"VHcollision": 1})
            continue

        """Update number of correct and incorrect payload"""
        
        if re.search('Payload Finished, INCORRECT', lines[i]) is not None:
            print(lines[i])
            num_incorrect += 1
            
        elif re.search('Payload Finished, CORRECT', lines[i]) is not None:
            print(lines[i])
            num_correct += 1
        
        """Update payload action: check / hit / safe"""

        if re.search("User check payload", lines[i]) is not None: 
            new_event.update({
                "payload_act": 0
            })
        elif re.search("User leaves payload by selecting HIT", lines[i]) is not None:
            new_event.update({
                "payload_act": 1
            })
        elif re.search("User leaves payload by selecting SAFE", lines[i]) is not None:
            new_event.update({
                "payload_act": 2
            })
            

        """Vehicle position, status and target"""
        if re.search('id: 1', lines[i]) is not None: 
            v1_x = re.sub("\D", "", lines[i].split(" ")[3])
            v1_y = re.sub("\D", "", lines[i].split(" ")[4])
            
            if len(lines[i].split(" ")) == 11:
                # For status 2 & status 3
                v1_status = re.sub("\D", "", lines[i].split(" ")[8])
                v1_target = re.sub("\n", "", lines[i].split(" ")[10])
            elif len(lines[i].split(" ")) >= 13: 
                v1_status = re.sub("\D", "", lines[i].split(" ")[10])
                v1_target = re.sub("\n", "", lines[i].split(" ")[12])
            else:
                # For status 1
                v1_status = re.sub("\D", "", lines[i].split(" ")[9])
                v1_target = re.sub("\n", "", lines[i].split(" ")[11])

            new_event.update({
                "v1_x": v1_x, 
                "v1_y": v1_y,
                "v1_status": v1_status,
                "v1_target": v1_target})
            continue

        elif re.search('id: 2', lines[i]) is not None: 
            v2_x = re.sub("\D", "", lines[i].split(" ")[3])
            v2_y = re.sub("\D", "", lines[i].split(" ")[4])
            if len(lines[i].split(" ")) <= 11:
                # For status 2 & status 3
                v2_status = re.sub("\D", "", lines[i].split(" ")[8])
                v2_target = re.sub("\n", "", lines[i].split(" ")[10])
            elif len(lines[i].split(" ")) >= 13: 
                v2_status = re.sub("\D", "", lines[i].split(" ")[10])
                v2_target = re.sub("\n", "", lines[i].split(" ")[12])
            else:
                # For status 1
                v2_status = re.sub("\D", "", lines[i].split(" ")[9])
                v2_target = re.sub("\n", "", lines[i].split(" ")[11])

            new_event.update({
                "v2_x": v2_x, 
                "v2_y": v2_y,
                "v2_status": v2_status,
                "v2_target": v2_target})
            continue
                    
        elif re.search('id: 3', lines[i]) is not None: 
            v3_x = re.sub("\D", "", lines[i].split(" ")[3])
            v3_y = re.sub("\D", "", lines[i].split(" ")[4])
            if len(lines[i].split(" ")) <= 11:
                # For status 2 & status 3
                v3_status = re.sub("\D", "", lines[i].split(" ")[8])
                v3_target = re.sub("\n", "", lines[i].split(" ")[10])
            elif len(lines[i].split(" ")) >= 13: 
                v3_status = re.sub("\D", "", lines[i].split(" ")[10])
                v3_target = re.sub("\n", "", lines[i].split(" ")[12])
            else:
                # For status 1
                v3_status = re.sub("\D", "", lines[i].split(" ")[9])
                v3_target = re.sub("\n", "", lines[i].split(" ")[11])

            new_event.update({
                "v3_x": v3_x, 
                "v3_y": v3_y,
                "v3_status": v3_status,
                "v3_target": v3_target})
            continue
                    
        elif re.search('id: 4', lines[i]) is not None: 
            v4_x = re.sub("\D", "", lines[i].split(" ")[3])
            v4_y = re.sub("\D", "", lines[i].split(" ")[4])
            if len(lines[i].split(" ")) <= 11:
                # For status 2 & status 3
                v4_status = re.sub("\D", "", lines[i].split(" ")[8])
                v4_target = re.sub("\n", "", lines[i].split(" ")[10])
            elif len(lines[i].split(" ")) >= 13: 
                v4_status = re.sub("\D", "", lines[i].split(" ")[10])
                v4_target = re.sub("\n", "", lines[i].split(" ")[12])
            else:
                # For status 1
                v4_status = re.sub("\D", "", lines[i].split(" ")[9])
                v4_target = re.sub("\n", "", lines[i].split(" ")[11])

            new_event.update({
                "v4_x": v4_x, 
                "v4_y": v4_y,
                "v4_status": v4_status,
                "v4_target": v4_target})
            continue

        elif re.search('id: 5', lines[i]) is not None: 
            v5_x = re.sub("\D", "", lines[i].split(" ")[3])
            v5_y = re.sub("\D", "", lines[i].split(" ")[4])
            if len(lines[i].split(" ")) <= 11:
                # For status 2 & status 3
                v5_status = re.sub("\D", "", lines[i].split(" ")[8])
                v5_target = re.sub("\n", "", lines[i].split(" ")[10])
            elif len(lines[i].split(" ")) >= 13:
                v5_status = re.sub("\D", "", lines[i].split(" ")[10])
                v5_target = re.sub("\n", "", lines[i].split(" ")[12])
            else:
                # For status 1
                v5_status = re.sub("\D", "", lines[i].split(" ")[9])
                v5_target = re.sub("\n", "", lines[i].split(" ")[11])

            new_event.update({
                "v5_x": v5_x, 
                "v5_y": v5_y,
                "v5_status": v5_status,
                "v5_target": v5_target})
            continue


        """Target position"""
        if re.search("name: A", lines[i]) is not None:
            ta_x = re.sub("\D", "", lines[i].split(" ")[3])
            ta_y = re.sub("\D", "", lines[i].split(" ")[4])
            new_event.update({
                "ta_x": ta_x,
                "ta_y": ta_y
            })
            continue

        elif re.search("name: B", lines[i]) is not None:
            tb_x = re.sub("\D", "", lines[i].split(" ")[3])
            tb_y = re.sub("\D", "", lines[i].split(" ")[4])
            new_event.update({
                "tb_x": tb_x,
                "tb_y": tb_y
            })
            continue

        elif re.search("name: C", lines[i]) is not None:
            tc_x = re.sub("\D", "", lines[i].split(" ")[3])
            tc_y = re.sub("\D", "", lines[i].split(" ")[4])
            new_event.update({
                "tc_x": tc_x,
                "tc_y": tc_y
            })
            continue

        elif re.search("name: D", lines[i]) is not None:
            td_x = re.sub("\D", "", lines[i].split(" ")[3])
            td_y = re.sub("\D", "", lines[i].split(" ")[4])
            new_event.update({
                "td_x": td_x,
                "td_y": td_y
            })
            continue

        elif re.search("name: E", lines[i]) is not None:
            te_x = re.sub("\D", "", lines[i].split(" ")[3])
            te_y = re.sub("\D", "", lines[i].split(" ")[4])
            new_event.update({
                "te_x": te_x,
                "te_y": te_y
            })
            continue

        elif re.search("name: F", lines[i]) is not None:
            tf_x = re.sub("\D", "", lines[i].split(" ")[3])
            tf_y = re.sub("\D", "", lines[i].split(" ")[4])
            new_event.update({
                "tf_x": tf_x,
                "tf_y": tf_y
            })
            continue
        
        elif re.search("name: G", lines[i]) is not None:
            tg_x = re.sub("\D", "", lines[i].split(" ")[3])
            tg_y = re.sub("\D", "", lines[i].split(" ")[4])
            new_event.update({
                "tg_x": tg_x,
                "tg_y": tg_y
            })
            continue

        """Harzard position"""
        if re.search("Hazards:", lines[i-1]) is not None:
            new_event.update({
                "h1_x": re.sub("\D", "", lines[i].split(" ")[0]), "h1_y": re.sub("\D", "", lines[i].split(" ")[1]),
                "h2_x": re.sub("\D", "", lines[i].split(" ")[2]), "h2_y": re.sub("\D", "", lines[i].split(" ")[3]),
                "h3_x": re.sub("\D", "", lines[i].split(" ")[4]), "h3_y": re.sub("\D", "", lines[i].split(" ")[5]),
                "h4_x": re.sub("\D", "", lines[i].split(" ")[6]), "h4_y": re.sub("\D", "", lines[i].split(" ")[7]),
                "h5_x": re.sub("\D", "", lines[i].split(" ")[8]), "h5_y": re.sub("\D", "", lines[i].split(" ")[9]),
                "h6_x": re.sub("\D", "", lines[i].split(" ")[10]), "h6_y": re.sub("\D", "", lines[i].split(" ")[11]),
                "h7_x": re.sub("\D", "", lines[i].split(" ")[12]), "h7_y": re.sub("\D", "", lines[i].split(" ")[13]),
                "h8_x": re.sub("\D", "", lines[i].split(" ")[14]), "h8_y": re.sub("\D", "", lines[i].split(" ")[15]),
                "h9_x": re.sub("\D", "", lines[i].split(" ")[16]), "h9_y": re.sub("\D", "", lines[i].split(" ")[17]),
                "h10_x": re.sub("\D", "", lines[i].split(" ")[18]), "h10_y": re.sub("\D", "", lines[i].split(" ")[19])
            })

        """if the line include "System Log", append current event to the event list, then create a new event"""
        if re.search("System Log", lines[i]) is not None:
            # print(f'System Log {i}')
            if new_event["event_id"] is not None:
                ## If new_event not empty and the current line include "System Log", 
                ## then append current new_event to event list and create a new new_event
                # print("Successfully append event")
                event_list.append(new_event)
                new_event = dict(zip(keys, [None] * len(keys)))
                event_num += 1

            event_time = lines[i].split(" ")[0] + " " + lines[i].split(" ")[1]

            new_event.update({
                "file_name": file_name,
                "event_id": event_num, 
                "time": event_time,
                "n_correct": num_correct,
                "n_incorrect": num_incorrect})
# Out:
# file name: /Users/chanhsu/Projects/HRI/uav_hsmm/HMM_Experiment/RAW_DATA/TK/HRB_TK_HW/HRB15_TK_HW.txt_fixed
# 2015-11-19 14:28:31.9    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 14:28:42.698    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 14:29:21.051    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 14:29:37.899    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 14:30:01.193    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 14:30:20.526    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 14:30:42.849    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 14:31:17.27    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 14:31:45.151    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 14:32:04.997    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 14:32:16.667    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 14:32:25.671    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 14:32:37.293    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 14:32:50.113    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 14:33:19.305    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 14:33:36.964    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 14:33:55.859    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 14:34:09.789    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 14:34:23.163    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 14:34:57.709    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 14:35:06.632    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 14:35:25.091    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 14:35:31.721    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 14:35:46.79    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 14:35:55.631    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 14:36:12.463    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 14:36:35.789    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 14:37:12.563    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 14:37:25.013    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 14:37:40.291    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 14:38:00.319    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# file name: /Users/chanhsu/Projects/HRI/uav_hsmm/HMM_Experiment/RAW_DATA/TK/HRB_TK_HW/HRB20_TK_HW.txt_fixed
# 2015-11-21 00:14:58.643    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-21 00:15:14.987    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-21 00:15:21.535    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-21 00:15:26.332    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-11-21 00:15:39.484    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-11-21 00:15:43.703    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-21 00:15:51.633    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-21 00:16:14.933    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-21 00:16:23.775    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-21 00:16:41.63    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-21 00:17:17.888    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-21 00:17:30.536    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-21 00:17:48.802    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-21 00:17:59.933    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-21 00:18:27.71    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-11-21 00:18:35.859    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-21 00:18:48.382    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-21 00:18:53.461    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-21 00:19:16.379    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-21 00:19:30.287    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-11-21 00:19:51.865    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-21 00:20:03.569    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-21 00:20:11.1    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-21 00:20:19.319    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-21 00:20:30.546    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-11-21 00:20:40.335    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-21 00:20:52.898    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-21 00:20:58.881    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-11-21 00:21:59.2    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-21 00:22:08.967    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-11-21 00:22:15.389    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-11-21 00:22:20.436    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-21 00:22:28.78    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-21 00:22:35.853    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-21 00:23:50.776    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-21 00:23:54.933    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-21 00:24:01.511    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-11-21 00:24:15.564    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-11-21 00:24:27.564    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# file name: /Users/chanhsu/Projects/HRI/uav_hsmm/HMM_Experiment/RAW_DATA/TK/HRB_TK_HW/HRB3_TK_HW.txt_fixed
# 2015-11-19 04:15:45.679    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 04:15:52.872    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 04:15:58.904    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 04:16:08.92    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 04:16:20.182    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 04:16:50.143    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 04:17:04.65    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 04:17:34.134    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 04:17:40.556    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 04:17:55.935    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 04:18:07.275    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 04:18:24.374    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 04:18:35.977    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 04:18:55.777    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 04:19:18.225    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 04:19:30.792    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 04:19:45.366    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 04:20:07.801    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 04:20:13.303    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 04:20:22.186    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 04:20:44.926    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 04:20:48.77    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 04:21:04.219    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 04:21:55.637    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 04:22:16.193    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 04:22:20.287    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 04:22:28.334    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 04:22:34.965    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 04:23:17.632    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 04:23:26.516    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 04:23:31.126    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 04:23:42.036    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 04:23:57.99    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 04:24:20.912    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 04:24:54.463    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 04:24:59.4    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 04:25:05.253    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 04:25:11.141    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# file name: /Users/chanhsu/Projects/HRI/uav_hsmm/HMM_Experiment/RAW_DATA/TK/HRB_TK_HW/HRB12_TK_HW.txt_fixed
# 2015-11-19 20:08:15.879    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:08:23.41    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:08:34.659    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:08:49.637    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 20:09:14.417    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 20:09:20.645    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:09:32.362    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:10:05.306    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:10:19.624    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:10:45.172    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:10:51.86    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:10:58.889    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:11:20.284    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:11:38.806    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:11:59.696    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:12:05.962    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:12:20.067    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:12:36.428    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:13:12.768    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:13:29.053    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:13:35.45    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:13:54.656    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:14:05.07    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:14:18.954    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:14:30.62    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:14:41.282    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:15:04.399    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:15:36.282    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 20:15:48.67    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:16:08.973    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:16:17.517    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 20:16:26.667    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:16:33.79    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:16:59.442    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# file name: /Users/chanhsu/Projects/HRI/uav_hsmm/HMM_Experiment/RAW_DATA/TK/HRB_TK_HW/HRB2_TK_HW.txt_fixed
# 2015-11-09 07:58:33.597    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 07:58:43.815    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 07:58:57.323    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 07:59:10.967    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 07:59:31.511    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-11-09 07:59:48.495    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 08:00:15.153    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 08:00:31.565    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 08:00:46.798    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 08:00:54.839    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 08:01:20.688    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 08:01:29.5    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 08:01:51.003    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-11-09 08:02:03.248    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 08:02:20.001    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 08:02:33.152    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 08:02:47.483    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 08:02:54.521    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 08:03:17.413    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 08:03:24.429    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 08:03:29.913    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 08:03:43.86    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 08:04:18.305    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 08:04:47.113    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 08:05:04.249    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 08:05:08.912    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 08:05:21.787    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 08:05:27.599    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-11-09 08:05:40.848    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 08:06:01.503    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-11-09 08:06:09.222    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-11-09 08:06:25.184    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 08:06:54.277    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 08:06:58.965    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 08:07:31.542    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-11-09 08:07:39.491    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 08:07:51.671    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# file name: /Users/chanhsu/Projects/HRI/uav_hsmm/HMM_Experiment/RAW_DATA/TK/HRB_TK_HW/HRB21_TK_HW.txt_fixed
# 2015-11-20 18:22:13.773    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 18:22:21.075    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 18:22:35.258    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 18:22:43.495    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 18:23:03.123    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 18:23:10.627    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 18:23:35.229    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 18:23:50.934    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 18:24:03.837    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 18:24:14.087    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 18:24:38.426    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 18:24:44.759    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 18:24:56.352    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 18:25:11.267    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 18:25:28.647    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 18:25:35.016    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 18:25:46.326    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 18:25:53.707    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 18:26:04.379    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 18:26:21.448    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 18:26:30.48    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 18:26:39.031    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 18:27:02.059    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 18:27:08.566    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 18:27:30.813    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 18:27:38.943    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 18:27:46.415    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 18:28:26.587    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 18:28:33.778    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 18:28:48.507    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 18:29:17.933    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 18:29:26.481    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 18:29:33.971    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 18:29:44.692    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 18:30:07.049    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 18:30:15.538    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 18:30:45.308    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 18:31:19.55    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 18:31:26.913    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 18:31:38.283    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# file name: /Users/chanhsu/Projects/HRI/uav_hsmm/HMM_Experiment/RAW_DATA/TK/HRB_TK_HW/HRB13_TK_HW.txt_fixed
# 2015-11-19 20:07:52.507    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:08:02.365    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:08:05.427    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:08:16.896    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 20:08:33.098    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:08:41.88    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:08:44.723    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:09:01.879    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:09:08.207    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:09:36.893    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 20:09:42.612    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:09:49.071    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:10:04.511    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:10:22.874    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:10:45.609    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:11:08.044    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:11:26.2    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:11:36.576    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:11:41.763    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 20:11:52.577    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:12:06.947    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:12:14.838    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:12:36.239    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:12:41.052    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:12:47.575    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 20:12:52.263    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:13:02.977    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:13:55.355    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 20:14:01.797    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:14:16.625    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:14:28.256    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 20:14:52.525    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:14:58.901    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:15:22.118    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:15:32.952    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:15:49.084    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:16:12.793    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 20:16:16.793    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 20:16:20.996    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:17:00.213    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:17:16.119    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:17:22.492    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# file name: /Users/chanhsu/Projects/HRI/uav_hsmm/HMM_Experiment/RAW_DATA/TK/HRB_TK_HW/HRB14_TK_HW.txt_fixed
# 2015-11-19 14:31:08.057    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 14:31:14.078    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 14:31:19.603    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 14:31:41.601    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 14:31:51.602    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 14:32:30.904    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 14:32:36.061    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 14:32:40.772    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 14:32:45.842    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 14:32:54.69    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 14:33:10.931    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 14:33:59.017    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 14:34:05.587    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 14:34:18.816    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 14:34:27.039    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 14:34:32.0    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 14:35:14.157    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 14:35:21.522    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 14:35:48.294    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 14:35:56.096    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 14:36:00.651    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 14:36:07.844    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 14:36:13.772    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 14:36:26.878    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 14:36:45.35    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 14:37:14.62    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 14:37:38.742    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 14:37:44.67    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 14:37:51.268    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 14:38:04.593    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 14:38:19.805    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 14:38:42.148    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 14:38:51.836    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 14:39:23.601    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 14:39:41.904    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 14:39:51.951    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 14:40:15.213    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 14:40:21.438    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# file name: /Users/chanhsu/Projects/HRI/uav_hsmm/HMM_Experiment/RAW_DATA/TK/HRB_TK_HW/HRB11_TK_HW.txt_fixed
# 2015-11-19 20:07:38.357    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:07:50.476    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:08:08.987    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:08:43.919    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:08:56.721    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:09:40.35    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:09:55.664    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:10:57.01    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:11:22.704    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:11:31.961    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:11:46.435    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:12:15.317    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:12:24.071    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:13:02.167    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:13:28.137    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:13:52.675    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:14:23.682    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 20:14:34.894    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 20:14:43.035    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 20:15:09.291    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:15:44.998    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:15:55.817    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:16:09.766    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:16:20.756    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:16:32.991    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 20:16:59.022    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 20:17:04.85    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# file name: /Users/chanhsu/Projects/HRI/uav_hsmm/HMM_Experiment/RAW_DATA/TK/HRB_TK_HW/HRB8_TK_HW.txt_fixed
# 2015-11-19 11:28:56.145    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:29:04.852    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:29:18.486    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:29:40.796    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 11:30:09.867    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:30:15.81    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:30:22.94    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:30:36.498    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:30:49.774    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:31:06.731    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:31:23.019    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:31:38.339    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:31:43.442    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:32:03.16    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:32:30.462    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:32:44.241    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:32:50.296    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:32:57.846    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:33:03.948    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 11:33:14.104    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 11:33:30.283    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:33:42.981    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:33:56.758    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:34:03.84    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:34:24.513    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:34:35.027    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:34:49.566    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:35:29.912    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:35:41.362    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 11:35:48.195    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 11:36:00.287    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 11:36:14.265    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:36:40.756    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:36:46.434    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:36:57.151    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 11:37:18.482    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:37:39.404    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:37:54.442    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:38:03.88    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:38:13.305    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# file name: /Users/chanhsu/Projects/HRI/uav_hsmm/HMM_Experiment/RAW_DATA/TK/HRB_TK_HW/HRB7_TK_HW.txt_fixed
# 2015-11-19 11:31:56.46    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:32:05.399    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:32:18.581    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:32:36.258    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 11:33:00.423    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 11:33:18.146    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:33:38.319    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:33:54.293    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:34:03.638    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:34:12.485    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:34:24.419    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:34:38.74    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:35:24.151    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:35:32.513    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:35:55.197    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:36:18.441    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:36:34.262    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:36:47.943    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:36:56.384    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:37:23.54    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:37:38.11    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:37:53.664    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:38:09.375    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:38:25.771    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:38:39.92    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:38:47.423    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:39:23.259    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:39:40.982    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 11:39:53.057    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:40:25.24    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:40:53.01    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 11:41:02.151    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:41:15.007    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:41:22.573    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# file name: /Users/chanhsu/Projects/HRI/uav_hsmm/HMM_Experiment/RAW_DATA/TK/HRB_TK_HW/HRB9_TK_HW.txt_fixed
# 2015-11-19 11:44:57.109    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:45:09.996    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:45:27.329    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:45:46.738    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 11:46:09.067    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:46:36.483    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:46:56.297    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:47:39.188    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:47:53.165    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:48:05.868    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:48:23.933    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:48:31.126    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:48:58.573    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:49:30.276    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:49:50.308    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:50:02.184    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:50:33.78    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:50:40.287    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:50:55.419    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:51:16.744    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:51:30.801    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:51:48.525    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:51:57.542    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:52:07.029    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:52:21.414    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 11:52:34.347    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:53:00.994    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:53:15.553    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:53:33.212    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:53:41.545    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:54:01.016    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 11:54:19.758    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# file name: /Users/chanhsu/Projects/HRI/uav_hsmm/HMM_Experiment/RAW_DATA/TK/HRB_TK_HW/HRB6_TK_HW.txt_fixed
# 2015-11-19 17:15:32.737    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 17:16:09.259    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 17:16:16.422    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 17:16:28.876    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 17:17:13.036    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 17:18:06.098    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 17:18:21.786    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 17:18:51.645    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 17:19:18.894    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 17:19:45.987    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 17:20:09.84    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 17:20:19.933    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 17:20:41.828    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 17:20:57.031    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 17:21:21.376    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 17:21:34.985    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 17:21:48.734    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 17:22:01.265    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 17:22:43.796    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 17:23:17.671    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 17:23:45.952    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 17:24:14.749    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 17:24:28.164    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 17:24:56.78    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# file name: /Users/chanhsu/Projects/HRI/uav_hsmm/HMM_Experiment/RAW_DATA/TK/HRB_TK_HW/HRB1_TK_HW.txt_fixed
# 2015-11-09 20:57:06.651    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 20:57:20.089    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 20:57:37.324    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 20:58:06.796    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 20:58:34.429    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-11-09 20:58:46.612    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 20:59:10.097    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-11-09 20:59:24.87    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 20:59:46.658    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 20:59:56.908    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 21:00:10.752    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 21:00:19.333    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 21:00:35.708    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 21:00:48.929    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 21:01:13.437    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 21:01:39.82    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 21:01:53.551    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 21:02:14.349    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 21:02:26.749    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 21:02:52.046    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-11-09 21:03:13.075    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 21:03:29.561    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 21:03:54.436    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 21:04:04.94    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 21:04:31.207    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 21:04:44.738    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 21:04:56.676    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 21:05:12.627    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 21:05:20.189    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-11-09 21:05:46.297    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-11-09 21:06:02.424    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 21:06:21.988    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-09 21:06:33.645    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# file name: /Users/chanhsu/Projects/HRI/uav_hsmm/HMM_Experiment/RAW_DATA/TK/HRB_TK_HW/HRB10_TK_HW.txt_fixed
# 2015-11-19 07:07:52.418    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 07:08:02.575    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 07:08:20.846    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 07:08:40.083    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 07:08:57.366    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 07:09:15.784    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 07:09:31.135    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 07:09:48.784    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 07:10:08.317    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 07:10:29.183    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 07:10:44.032    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 07:10:54.935    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 07:11:13.336    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 07:11:25.574    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 07:11:42.152    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 07:12:04.197    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 07:12:21.209    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 07:12:37.753    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 07:12:48.787    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 07:13:02.153    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 07:13:16.631    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 07:13:30.118    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 07:13:38.278    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 07:13:49.662    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 07:14:02.508    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 07:14:15.879    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 07:14:32.18    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 07:14:54.55    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 07:15:14.421    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 07:15:32.612    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 07:15:50.875    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 07:15:58.692    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 07:16:11.118    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 07:16:16.545    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 07:16:32.022    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 07:16:48.67    Vehicle: 5 Payload Finished, CORRECT -1,-1

# %% [markdown]
# ### Save file
# 1. transform the list into pandas dataframe
# 2. save as csv file

# %%
df = pd.DataFrame(event_list)

df.to_csv(csv_file, sep=",")
