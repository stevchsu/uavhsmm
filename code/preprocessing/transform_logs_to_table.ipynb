# %%
import pandas as pd
import numpy as np
import codecs
import re
import os
from datetime import datetime

# %% [markdown]
# ### Goal
# - Transform the system log into dataframe
# - Each row record all activities happened within 1 second
# - User actions include watch (default action), add way point, set goal, apply automation, engage payload
#     - Apply automation is an one-shot action, user apply the system suggestion and the action finished immediately.
#
# - Description of coding
#     - vehicle status
#         - 1: moving
#         - 2: arrived target
#         - 3: engage payload

# %% [markdown]
# ### Set source directory, target file and keys

# %%
root_dir = "/Users/chanhsu/Projects/HRI/uav_hsmm/HMM_Experiment/RAW_DATA/TW/HRB_HW/"
csv_file = "/Users/chanhsu/Projects/HRI/uav_hsmm/uav_hsmm/data/data_20221107/Tw/TW_HRB_HW.csv"

keys = (
    "file_name", "event_id", "time", 
    "action", "payload_act", "n_correct", "n_incorrect",
    "v1_x", "v1_y", "v2_x", "v2_y", "v3_x", "v3_y", "v4_x", "v4_y", "v5_x", "v5_y",
    "v1_target", "v2_target", "v3_target", "v4_target", "v5_target",
    "v1_status", "v2_status", "v3_status", "v4_status", "v5_status", 
    "ta_x", "ta_y", "tb_x", "tb_y", "tc_x", "tc_y", "td_x", "td_y", "te_x", "te_y", "tf_x", "tf_y", "tg_x", "tg_y",
    "h1_x", "h1_y", "h2_x", "h2_y", "h3_x", "h3_y", "h4_x", "h4_y", "h5_x", "h5_y", 
    "h6_x", "h6_y", "h7_x", "h7_y", "h8_x", "h8_y", "h9_x", "h9_y", "h10_x", "h10_y",
)
event_list = list()

# %%
os.listdir(root_dir)
# Out:
# ['LRC11_TK_LW.txt_fixed',
#  'LRC2_TK_LW.txt_fixed',
#  'LRC25_TK_LW.txt_fixed',
#  'LRC3_TK_LW.txt_fixed',
#  'LRC17_TK_LW.txt_fixed',
#  'LRC10_TK_LW.txt_fixed',
#  'LRC4_TK_LW.txt_fixed',
#  'LRC15_TK_LW.txt_fixed',
#  'LRC1_TK_LW.txt_fixed',
#  'LRC6_TK_LW.txt_fixed',
#  'LRC12_TK_LW.txt_fixed',
#  'LRC9_TK_LW.txt_fixed',
#  'LRC7_TK_LW.txt_fixed',
#  'desktop.ini',
#  'LRC8_TK_LW.txt_fixed',
#  'LRC26_TK_LW.txt_fixed']

# %% [markdown]
# ### Extract contents from log files

# %%
for file_name in os.listdir(root_dir):
    
    if file_name == "desktop.ini": 
        continue

    ## Initialize values
    event_num = 0
    num_correct = 0
    num_incorrect = 0
    action = None


    ## Load file content
    file_path = root_dir + file_name
    file = codecs.open(file_path, 'r', encoding='utf-8')
    lines  = file.readlines()
    # print(f"""file name: {file_path}""")

    ## remove first line from list (experiment start)
    lines.pop(0)

    new_event = dict(zip(keys, [None] * len(keys)))

    ## Start to transform
    # for i in range(len(lines)):
    for i in range(len(lines)):

        # initialize row
        if i == 0:
            new_event = dict(zip(keys, [None] * len(keys)))
    
        # debug message
        # if i % 10000 == 0:
        #     print(f"""line: {i}, content: {lines[i]}""")

        ## Update action
        if event_num == 0:
            new_event.update({"action": "watch"})
        
        elif re.search('WP add start', lines[i]) is not None:
            new_event.update({"action": "addWP" })
            continue

        elif re.search('WP add end', lines[i]) is not None or re.search('WP add canceled', lines[i]) is not None or re.search('Goal change end', lines[i]) is not None:
            new_event.update({"action": "watch" })
            continue

        elif re.search('Payload Finished', lines[i]) is not None:
            new_event.update({"action": "watch" })
        
        elif re.search('Payload Engaged', lines[i]) is not None:
            new_event.update({"action": "engagePayload" })
            continue
        
        # elif re.search('Payload Finished', lines[i]) is not None:
        #     new_event.update({"action": "watch" })
        #     continue

        elif re.search('Goal set start', lines[i]) is not None:
            new_event.update({"action": "setGoal" })
            continue
        
        # elif re.search('Goal change end', lines[i]) is not None:
        #     new_event.update({"action": "watch" })
        #     continue  
        
        elif re.search('User applies automation', lines[i]) is not None:
            new_event.update({"action": "applyAutomation" })
            continue

        ## Update number of correct and incorrect payload
        if re.search('Payload Finished, INCORRECT', lines[i]) is not None:
            print(lines[i])
            num_incorrect += 1
            
        elif re.search('Payload Finished, CORRECT', lines[i]) is not None:
            print(lines[i])
            num_correct += 1
        
        ## Update payload action: check / hit / safe
        if re.search("User check payload", lines[i]) is not None: 
            new_event.update({
                "payload_act": 0
            })
        elif re.search("User leaves payload by selecting HIT", lines[i]) is not None:
            new_event.update({
                "payload_act": 1
            })
        elif re.search("User leaves payload by selecting SAFE", lines[i]) is not None:
            new_event.update({
                "payload_act": 2
            })
            

        ## Vehicle position, status and target
        if re.search('id: 1', lines[i]) is not None: 
            v1_x = re.sub("\D", "", lines[i].split(" ")[3])
            v1_y = re.sub("\D", "", lines[i].split(" ")[4])

            if len(lines[i].split(" ")) == 11:
                # For status 2 & status 3
                v1_status = re.sub("\D", "", lines[i].split(" ")[8])
                v1_target = re.sub("\n", "", lines[i].split(" ")[10])
            elif len(lines[i].split(" ")) >= 13: 
                v1_status = re.sub("\D", "", lines[i].split(" ")[10])
                v1_target = re.sub("\n", "", lines[i].split(" ")[12])
            else:
                # For status 1
                v1_status = re.sub("\D", "", lines[i].split(" ")[9])
                v1_target = re.sub("\n", "", lines[i].split(" ")[11])

            new_event.update({
                "v1_x": v1_x, 
                "v1_y": v1_y,
                "v1_status": v1_status,
                "v1_target": v1_target})
            continue

        elif re.search('id: 2', lines[i]) is not None: 
            v2_x = re.sub("\D", "", lines[i].split(" ")[3])
            v2_y = re.sub("\D", "", lines[i].split(" ")[4])
            if len(lines[i].split(" ")) <= 11:
                # For status 2 & status 3
                v2_status = re.sub("\D", "", lines[i].split(" ")[8])
                v2_target = re.sub("\n", "", lines[i].split(" ")[10])
            elif len(lines[i].split(" ")) >= 13: 
                v2_status = re.sub("\D", "", lines[i].split(" ")[10])
                v2_target = re.sub("\n", "", lines[i].split(" ")[12])
            else:
                # For status 1
                v2_status = re.sub("\D", "", lines[i].split(" ")[9])
                v2_target = re.sub("\n", "", lines[i].split(" ")[11])

            new_event.update({
                "v2_x": v2_x, 
                "v2_y": v2_y,
                "v2_status": v2_status,
                "v2_target": v2_target})
            continue
                    
        elif re.search('id: 3', lines[i]) is not None: 
            v3_x = re.sub("\D", "", lines[i].split(" ")[3])
            v3_y = re.sub("\D", "", lines[i].split(" ")[4])
            if len(lines[i].split(" ")) <= 11:
                # For status 2 & status 3
                v3_status = re.sub("\D", "", lines[i].split(" ")[8])
                v3_target = re.sub("\n", "", lines[i].split(" ")[10])
            elif len(lines[i].split(" ")) >= 13: 
                v3_status = re.sub("\D", "", lines[i].split(" ")[10])
                v3_target = re.sub("\n", "", lines[i].split(" ")[12])
            else:
                # For status 1
                v3_status = re.sub("\D", "", lines[i].split(" ")[9])
                v3_target = re.sub("\n", "", lines[i].split(" ")[11])

            new_event.update({
                "v3_x": v3_x, 
                "v3_y": v3_y,
                "v3_status": v3_status,
                "v3_target": v3_target})
            continue
                    
        elif re.search('id: 4', lines[i]) is not None: 
            v4_x = re.sub("\D", "", lines[i].split(" ")[3])
            v4_y = re.sub("\D", "", lines[i].split(" ")[4])
            if len(lines[i].split(" ")) <= 11:
                # For status 2 & status 3
                v4_status = re.sub("\D", "", lines[i].split(" ")[8])
                v4_target = re.sub("\n", "", lines[i].split(" ")[10])
            elif len(lines[i].split(" ")) >= 13: 
                v4_status = re.sub("\D", "", lines[i].split(" ")[10])
                v4_target = re.sub("\n", "", lines[i].split(" ")[12])
            else:
                # For status 1
                v4_status = re.sub("\D", "", lines[i].split(" ")[9])
                v4_target = re.sub("\n", "", lines[i].split(" ")[11])

            new_event.update({
                "v4_x": v4_x, 
                "v4_y": v4_y,
                "v4_status": v4_status,
                "v4_target": v4_target})
            continue

        elif re.search('id: 5', lines[i]) is not None: 
            v5_x = re.sub("\D", "", lines[i].split(" ")[3])
            v5_y = re.sub("\D", "", lines[i].split(" ")[4])
            if len(lines[i].split(" ")) <= 11:
                # For status 2 & status 3
                v5_status = re.sub("\D", "", lines[i].split(" ")[8])
                v5_target = re.sub("\n", "", lines[i].split(" ")[10])
            elif len(lines[i].split(" ")) >= 13:
                v5_status = re.sub("\D", "", lines[i].split(" ")[10])
                v5_target = re.sub("\n", "", lines[i].split(" ")[12])
            else:
                # For status 1
                v5_status = re.sub("\D", "", lines[i].split(" ")[9])
                v5_target = re.sub("\n", "", lines[i].split(" ")[11])

            new_event.update({
                "v5_x": v5_x, 
                "v5_y": v5_y,
                "v5_status": v5_status,
                "v5_target": v5_target})
            continue


        ## Target position
        if re.search("name: A", lines[i]) is not None:
            ta_x = re.sub("\D", "", lines[i].split(" ")[3])
            ta_y = re.sub("\D", "", lines[i].split(" ")[4])
            new_event.update({
                "ta_x": ta_x,
                "ta_y": ta_y
            })
            continue

        elif re.search("name: B", lines[i]) is not None:
            tb_x = re.sub("\D", "", lines[i].split(" ")[3])
            tb_y = re.sub("\D", "", lines[i].split(" ")[4])
            new_event.update({
                "tb_x": tb_x,
                "tb_y": tb_y
            })
            continue

        elif re.search("name: C", lines[i]) is not None:
            tc_x = re.sub("\D", "", lines[i].split(" ")[3])
            tc_y = re.sub("\D", "", lines[i].split(" ")[4])
            new_event.update({
                "tc_x": tc_x,
                "tc_y": tc_y
            })
            continue

        elif re.search("name: D", lines[i]) is not None:
            td_x = re.sub("\D", "", lines[i].split(" ")[3])
            td_y = re.sub("\D", "", lines[i].split(" ")[4])
            new_event.update({
                "td_x": td_x,
                "td_y": td_y
            })
            continue

        elif re.search("name: E", lines[i]) is not None:
            te_x = re.sub("\D", "", lines[i].split(" ")[3])
            te_y = re.sub("\D", "", lines[i].split(" ")[4])
            new_event.update({
                "te_x": te_x,
                "te_y": te_y
            })
            continue

        elif re.search("name: F", lines[i]) is not None:
            tf_x = re.sub("\D", "", lines[i].split(" ")[3])
            tf_y = re.sub("\D", "", lines[i].split(" ")[4])
            new_event.update({
                "tf_x": tf_x,
                "tf_y": tf_y
            })
            continue
        
        elif re.search("name: G", lines[i]) is not None:
            tg_x = re.sub("\D", "", lines[i].split(" ")[3])
            tg_y = re.sub("\D", "", lines[i].split(" ")[4])
            new_event.update({
                "tg_x": tg_x,
                "tg_y": tg_y
            })
            continue

        
        ## Harzard position
        if re.search("Hazards:", lines[i-1]) is not None:
            new_event.update({
                "h1_x": re.sub("\D", "", lines[i].split(" ")[0]), "h1_y": re.sub("\D", "", lines[i].split(" ")[1]),
                "h2_x": re.sub("\D", "", lines[i].split(" ")[2]), "h2_y": re.sub("\D", "", lines[i].split(" ")[3]),
                "h3_x": re.sub("\D", "", lines[i].split(" ")[4]), "h3_y": re.sub("\D", "", lines[i].split(" ")[5]),
                "h4_x": re.sub("\D", "", lines[i].split(" ")[6]), "h4_y": re.sub("\D", "", lines[i].split(" ")[7]),
                "h5_x": re.sub("\D", "", lines[i].split(" ")[8]), "h5_y": re.sub("\D", "", lines[i].split(" ")[9]),
                "h6_x": re.sub("\D", "", lines[i].split(" ")[10]), "h6_y": re.sub("\D", "", lines[i].split(" ")[11]),
                "h7_x": re.sub("\D", "", lines[i].split(" ")[12]), "h7_y": re.sub("\D", "", lines[i].split(" ")[13]),
                "h8_x": re.sub("\D", "", lines[i].split(" ")[14]), "h8_y": re.sub("\D", "", lines[i].split(" ")[15]),
                "h9_x": re.sub("\D", "", lines[i].split(" ")[16]), "h9_y": re.sub("\D", "", lines[i].split(" ")[17]),
                "h10_x": re.sub("\D", "", lines[i].split(" ")[18]), "h10_y": re.sub("\D", "", lines[i].split(" ")[19])
            })

        ## if the line include "System Log", then create a new event
        if re.search("System Log", lines[i]) is not None:

            if new_event["event_id"] is not None:
                # If new_event not empty and the current line include "System Log", 
                # then append current new_event to event list and create a new new_event

                event_list.append(new_event)
                new_event = dict(zip(keys, [None] * len(keys)))
                event_num += 1

            event_time = lines[i].split(" ")[0] + " " + lines[i].split(" ")[1]

            new_event.update({
                "file_name": file_name,
                "event_id": event_num, 
                "time": event_time,
                "n_correct": num_correct,
                "n_incorrect": num_incorrect})
# Out:
# 2015-11-12 21:44:48.655    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 21:45:36.289    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-11-12 21:46:17.877    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 21:46:23.861    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 21:46:47.878    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 21:47:05.373    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 21:47:24.862    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 21:47:47.815    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 21:48:11.859    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-11-12 21:48:49.307    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-11-12 21:49:29.727    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 21:49:40.406    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 21:50:51.076    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 21:51:05.123    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-11-12 21:51:22.45    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-11-12 21:51:28.263    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 21:51:49.65    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-11-12 21:51:56.057    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 21:52:19.832    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 21:53:05.568    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-11-12 21:53:11.193    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 21:53:28.19    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-11-12 21:54:11.818    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 04:38:24.464    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 04:39:21.917    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 04:40:32.851    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 04:40:38.851    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 04:40:59.061    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 04:41:09.437    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 04:41:24.435    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 04:41:42.969    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 04:42:13.925    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 04:43:11.889    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 04:43:18.978    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-11-12 04:43:49.149    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 04:44:16.8    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 04:44:37.99    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 04:44:59.088    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 04:45:20.31    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 04:46:29.874    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 04:46:40.254    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 04:46:45.226    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 04:47:00.692    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 04:47:17.481    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 04:47:38.956    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 11:34:15.182    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 11:35:10.606    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 11:36:02.565    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 11:36:11.7    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 11:36:33.597    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 11:37:00.185    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 11:37:14.903    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 11:37:34.29    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 11:38:20.619    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 11:39:28.354    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 11:39:51.047    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 11:40:03.532    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 11:40:37.951    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 11:41:10.267    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 11:41:30.067    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 11:41:46.023    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 11:42:01.236    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 11:42:42.287    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 11:43:17.395    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 17:44:10.261    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 17:44:51.978    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 17:45:39.988    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 17:45:47.629    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 17:46:12.077    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-11-12 17:46:37.792    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 17:46:47.994    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 17:47:13.799    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 17:48:08.264    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 17:48:38.481    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 17:49:00.369    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 17:49:12.524    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 17:50:29.95    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 17:50:45.965    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-11-12 17:50:55.637    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 17:51:09.988    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-11-12 17:52:08.797    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-11-12 17:52:31.082    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 17:52:41.254    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 17:53:20.898    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 16:13:58.448    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 16:14:56.939    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 16:15:54.746    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 16:16:05.135    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 16:16:27.633    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 16:17:10.691    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 16:17:17.165    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 16:17:58.039    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 16:18:27.806    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 16:19:00.871    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 16:19:23.368    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 16:19:50.514    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 16:20:20.125    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 16:20:45.306    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 16:21:36.211    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 16:21:41.936    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 16:21:59.255    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 16:22:35.309    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 16:22:50.129    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 16:22:57.963    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 16:23:17.416    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 16:23:32.05    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 08:34:12.701    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-11-12 08:34:49.288    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 08:35:56.36    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-11-12 08:36:00.985    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 08:36:21.665    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 08:36:42.154    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 08:37:17.545    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-11-12 08:38:06.49    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-11-12 08:39:16.956    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 08:39:30.592    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 08:39:40.997    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 08:41:26.75    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-11-12 08:41:58.983    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-11-12 08:42:44.808    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-11-12 08:42:55.998    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 17:37:26.741    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-11-12 17:38:27.021    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-11-12 17:39:15.381    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-11-12 17:39:24.803    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 17:40:17.83    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-11-12 17:40:43.334    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 17:41:13.164    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-11-12 17:41:48.182    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-11-12 17:42:13.937    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-11-12 17:43:38.996    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-11-12 17:44:01.834    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-11-12 17:44:21.668    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-11-12 17:44:45.868    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-11-12 17:45:28.591    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-11-12 17:45:50.723    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 17:46:08.892    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 17:46:28.869    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-11-13 00:36:00.315    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-11-13 00:37:44.906    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-11-13 00:37:59.521    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-13 00:38:06.459    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-13 00:38:39.921    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-11-13 00:39:05.367    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-13 00:39:21.89    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-13 00:39:36.42    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-13 00:39:57.216    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-13 00:40:39.467    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-13 00:41:11.897    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-13 00:41:34.606    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-13 00:41:46.895    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-13 00:42:57.408    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-13 00:43:22.912    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-13 00:43:39.695    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-13 00:44:01.774    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-11-13 00:44:19.714    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-13 00:44:51.292    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-13 00:45:20.447    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-11 13:51:45.615    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-11 13:52:41.156    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-11 13:53:22.439    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-11 13:53:34.32    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-11 13:53:49.44    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-11-11 13:54:16.224    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-11-11 13:54:35.11    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-11 13:55:35.582    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-11 13:55:45.501    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-11 13:56:08.265    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-11 13:57:44.606    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-11 13:57:55.512    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-11 13:58:15.901    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-11 13:58:22.971    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-11-11 13:58:58.803    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-11 13:59:14.914    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-11 13:59:40.249    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-11-11 13:59:54.553    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-11 14:00:00.823    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-11 14:00:50.134    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 17:36:42.505    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 17:37:00.873    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-11-12 17:37:29.845    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 17:37:43.663    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 17:38:12.98    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 17:38:48.688    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 17:39:28.285    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 17:39:40.833    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 17:40:24.148    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 17:40:41.389    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 17:40:58.601    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 17:41:31.115    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 17:42:04.042    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 17:42:52.821    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-11-12 17:43:08.335    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 17:43:22.455    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 17:43:49.963    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 17:44:03.713    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 17:44:38.609    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 17:45:05.882    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 21:44:50.524    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-11-12 21:45:47.658    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-11-12 21:46:23.765    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 21:46:34.078    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 21:46:54.273    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 21:47:06.517    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 21:47:53.473    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-11-12 21:48:09.107    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 21:48:55.42    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-11-12 21:49:50.276    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 21:50:23.005    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 21:50:59.693    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 21:51:31.456    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 21:51:53.659    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-11-12 21:52:06.432    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 21:52:53.909    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 21:53:15.591    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-11-12 21:53:22.195    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 21:53:45.829    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-11-12 21:54:03.814    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 20:02:40.187    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 20:03:04.03    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-11-12 20:03:57.271    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 20:04:57.659    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 20:05:34.256    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 20:06:00.6    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 20:06:44.532    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 20:07:07.494    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 20:08:00.718    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-11-12 20:09:11.281    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-11-12 11:47:35.222    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-11-12 11:48:21.521    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-11-12 11:49:06.435    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 11:49:23.082    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 11:49:35.282    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 11:49:48.637    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 11:50:08.097    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 11:50:16.773    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 11:51:03.044    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 11:51:15.141    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 11:51:36.311    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 11:51:53.644    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 11:52:02.458    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 11:52:40.306    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 11:53:53.197    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 11:54:13.181    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 11:54:48.049    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 11:54:58.706    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 11:56:29.833    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 11:56:41.72    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 07:17:58.017    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 07:18:17.661    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-11-12 07:18:46.088    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 07:18:58.801    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 07:19:47.47    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 07:20:27.976    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 07:21:07.418    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 07:21:19.454    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 07:21:33.044    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 07:22:41.344    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 07:23:21.795    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 07:24:01.287    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 07:24:24.326    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-11-12 07:24:32.36    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-11-12 07:25:14.686    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 07:25:30.101    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 07:25:43.013    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-12 07:25:56.072    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-21 00:35:22.957    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-11-21 00:35:54.278    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-11-21 00:36:33.387    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-21 00:36:44.044    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-21 00:37:12.897    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-21 00:37:40.601    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-21 00:37:47.867    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-21 00:38:23.416    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-21 00:39:00.15    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-11-21 00:39:08.775    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-21 00:40:06.132    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-21 00:40:19.247    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-21 00:41:43.378    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-21 00:41:52.3    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-11-21 00:42:11.941    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-21 00:42:35.684    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-21 00:43:03.944    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-21 00:43:14.601    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-21 00:43:29.168    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-21 00:43:52.906    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-11-21 00:43:58.2    Vehicle: 1 Payload Finished, CORRECT -1,-1

# %% [markdown]
# ### tranform the list to pandas dataframe

# %%
df = pd.DataFrame(event_list)

df.to_csv(csv_file, sep=",")
