# %%
import pandas as pd
import numpy as np
import codecs
import re
import os
from datetime import datetime

# %% [markdown]
# ### Goal
# - Transform the system log into dataframe
# - Each row record all activities happened within 1 second
# - User actions include watch (default action), add way point, set goal, apply automation, engage payload
#     - Apply automation is an one-shot action, user apply the system suggestion and the action finished immediately.
#
# - Description of coding
#     - vehicle status
#         - 1: moving
#         - 2: arrived target
#         - 3: engage payload

# %% [markdown]
# ### Set source directory, target file and keys

# %%
root_dir = "/Users/chanhsu/Projects/HRI/uav_hsmm/HMM_Experiment/RAW_DATA/US/LRB_US_HW/"
csv_file = "/Users/chanhsu/Projects/HRI/uav_hsmm/uav_hsmm/data/data_20221107/US/US_LRB_HW.csv"

keys = (
    "file_name", "event_id", "time", 
    "action", "payload_act", "n_correct", "n_incorrect",
    "v1_x", "v1_y", "v2_x", "v2_y", "v3_x", "v3_y", "v4_x", "v4_y", "v5_x", "v5_y",
    "v1_target", "v2_target", "v3_target", "v4_target", "v5_target",
    "v1_status", "v2_status", "v3_status", "v4_status", "v5_status", 
    "ta_x", "ta_y", "tb_x", "tb_y", "tc_x", "tc_y", "td_x", "td_y", "te_x", "te_y", "tf_x", "tf_y", "tg_x", "tg_y",
    "h1_x", "h1_y", "h2_x", "h2_y", "h3_x", "h3_y", "h4_x", "h4_y", "h5_x", "h5_y", 
    "h6_x", "h6_y", "h7_x", "h7_y", "h8_x", "h8_y", "h9_x", "h9_y", "h10_x", "h10_y",
)
event_list = list()

# %%
os.listdir(root_dir)
# Out:
# ['LRB2_US_HW.txt_fixed',
#  'LRB10_US_HW.txt_fixed',
#  'LRB11_US_HW.txt_fixed',
#  'LRB4_US_HW.txt_fixed',
#  'LRB3_US_HW.txt_fixed',
#  'LRB16_US_HW.txt_fixed',
#  'LRB13_US_HW.txt_fixed',
#  'LRB6_US_HW.txt_fixed',
#  'LRB9_US_HW.txt_fixed',
#  'LRB1_US_HW.txt_fixed',
#  'LRB14_US_HW.txt_fixed',
#  'desktop.ini',
#  'LRB15_US_HW.txt_fixed',
#  'LRB7_US_HW.txt_fixed',
#  'LRB12_US_HW.txt_fixed',
#  'LRB8_US_HW.txt_fixed']

# %% [markdown]
# ### Extract contents from log files

# %%
for file_name in os.listdir(root_dir):
    
    if file_name == "desktop.ini": 
        continue

    ## Initialize values
    event_num = 0
    num_correct = 0
    num_incorrect = 0
    action = None


    ## Load file content
    file_path = root_dir + file_name
    file = codecs.open(file_path, 'r', encoding='utf-8')
    lines  = file.readlines()
    # print(f"""file name: {file_path}""")

    ## remove first line from list (experiment start)
    lines.pop(0)

    new_event = dict(zip(keys, [None] * len(keys)))

    ## Start to transform
    # for i in range(len(lines)):
    for i in range(len(lines)):

        # initialize row
        if i == 0:
            new_event = dict(zip(keys, [None] * len(keys)))
    
        # debug message
        # if i % 10000 == 0:
        #     print(f"""line: {i}, content: {lines[i]}""")

        ## Update action
        if re.search('WP add start', lines[i]) is not None:
            new_event.update({"action": "addWP" })
            continue

        elif re.search('WP add end', lines[i]) is not None or re.search('WP add canceled', lines[i]) is not None or re.search('Goal change end', lines[i]) is not None:
            new_event.update({"action": "watch" })
            continue

        elif re.search('Payload Finished', lines[i]) is not None:
            new_event.update({"action": "watch" })
        
        elif re.search('Payload Engaged', lines[i]) is not None:
            new_event.update({"action": "engagePayload" })
            continue
        
        # elif re.search('Payload Finished', lines[i]) is not None:
        #     new_event.update({"action": "watch" })
        #     continue

        elif re.search('Goal set start', lines[i]) is not None:
            new_event.update({"action": "setGoal" })
            continue
        
        # elif re.search('Goal change end', lines[i]) is not None:
        #     new_event.update({"action": "watch" })
        #     continue  
        
        elif re.search('User applies automation', lines[i]) is not None:
            new_event.update({"action": "applyAutomation" })
            continue

        ## Update number of correct and incorrect payload
        if re.search('Payload Finished, INCORRECT', lines[i]) is not None:
            print(lines[i])
            num_incorrect += 1
            
        elif re.search('Payload Finished, CORRECT', lines[i]) is not None:
            print(lines[i])
            num_correct += 1
        
        ## Update payload action: check / hit / safe
        if re.search("User check payload", lines[i]) is not None: 
            new_event.update({
                "payload_act": 0
            })
        elif re.search("User leaves payload by selecting HIT", lines[i]) is not None:
            new_event.update({
                "payload_act": 1
            })
        elif re.search("User leaves payload by selecting SAFE", lines[i]) is not None:
            new_event.update({
                "payload_act": 2
            })
            

        ## Vehicle position, status and target
        if re.search('id: 1', lines[i]) is not None: 
            v1_x = re.sub("\D", "", lines[i].split(" ")[3])
            v1_y = re.sub("\D", "", lines[i].split(" ")[4])

            if len(lines[i].split(" ")) == 11:
                # For status 2 & status 3
                v1_status = re.sub("\D", "", lines[i].split(" ")[8])
                v1_target = lines[i].split(" ")[10]
            elif len(lines[i].split(" ")) >= 13: 
                v1_status = re.sub("\D", "", lines[i].split(" ")[10])
                v1_target = lines[i].split(" ")[12]
            else:
                # For status 1
                v1_status = re.sub("\D", "", lines[i].split(" ")[9])
                v1_target = lines[i].split(" ")[11]

            new_event.update({
                "v1_x": v1_x, 
                "v1_y": v1_y,
                "v1_status": v1_status,
                "v1_target": v1_target})
            continue

        elif re.search('id: 2', lines[i]) is not None: 
            v2_x = re.sub("\D", "", lines[i].split(" ")[3])
            v2_y = re.sub("\D", "", lines[i].split(" ")[4])
            if len(lines[i].split(" ")) <= 11:
                # For status 2 & status 3
                v2_status = re.sub("\D", "", lines[i].split(" ")[8])
                v2_target = lines[i].split(" ")[10]
            elif len(lines[i].split(" ")) >= 13: 
                v2_status = re.sub("\D", "", lines[i].split(" ")[10])
                v2_target = lines[i].split(" ")[12]
            else:
                # For status 1
                v2_status = re.sub("\D", "", lines[i].split(" ")[9])
                v2_target = lines[i].split(" ")[11]

            new_event.update({
                "v2_x": v2_x, 
                "v2_y": v2_y,
                "v2_status": v2_status,
                "v2_target": v2_target})
            continue
                    
        elif re.search('id: 3', lines[i]) is not None: 
            v3_x = re.sub("\D", "", lines[i].split(" ")[3])
            v3_y = re.sub("\D", "", lines[i].split(" ")[4])
            if len(lines[i].split(" ")) <= 11:
                # For status 2 & status 3
                v3_status = re.sub("\D", "", lines[i].split(" ")[8])
                v3_target = lines[i].split(" ")[10]
            elif len(lines[i].split(" ")) >= 13: 
                v3_status = re.sub("\D", "", lines[i].split(" ")[10])
                v3_target = lines[i].split(" ")[12]
            else:
                # For status 1
                v3_status = re.sub("\D", "", lines[i].split(" ")[9])
                v3_target = lines[i].split(" ")[11]

            new_event.update({
                "v3_x": v3_x, 
                "v3_y": v3_y,
                "v3_status": v3_status,
                "v3_target": v3_target})
            continue
                    
        elif re.search('id: 4', lines[i]) is not None: 
            v4_x = re.sub("\D", "", lines[i].split(" ")[3])
            v4_y = re.sub("\D", "", lines[i].split(" ")[4])
            if len(lines[i].split(" ")) <= 11:
                # For status 2 & status 3
                v4_status = re.sub("\D", "", lines[i].split(" ")[8])
                v4_target = lines[i].split(" ")[10]
            elif len(lines[i].split(" ")) >= 13: 
                v4_status = re.sub("\D", "", lines[i].split(" ")[10])
                v4_target = lines[i].split(" ")[12]
            else:
                # For status 1
                v4_status = re.sub("\D", "", lines[i].split(" ")[9])
                v4_target = lines[i].split(" ")[11]

            new_event.update({
                "v4_x": v4_x, 
                "v4_y": v4_y,
                "v4_status": v4_status,
                "v4_target": v4_target})
            continue

        elif re.search('id: 5', lines[i]) is not None: 
            v5_x = re.sub("\D", "", lines[i].split(" ")[3])
            v5_y = re.sub("\D", "", lines[i].split(" ")[4])
            if len(lines[i].split(" ")) <= 11:
                # For status 2 & status 3
                v5_status = re.sub("\D", "", lines[i].split(" ")[8])
                v5_target = lines[i].split(" ")[10]
            elif len(lines[i].split(" ")) >= 13:
                v5_status = re.sub("\D", "", lines[i].split(" ")[10])
                v5_target = lines[i].split(" ")[12]
            else:
                # For status 1
                v5_status = re.sub("\D", "", lines[i].split(" ")[9])
                v5_target = lines[i].split(" ")[11]

            new_event.update({
                "v5_x": v5_x, 
                "v5_y": v5_y,
                "v5_status": v5_status,
                "v5_target": v5_target})
            continue


        ## Target position
        if re.search("name: A", lines[i]) is not None:
            ta_x = re.sub("\D", "", lines[i].split(" ")[3])
            ta_y = re.sub("\D", "", lines[i].split(" ")[4])
            new_event.update({
                "ta_x": ta_x,
                "ta_y": ta_y
            })
            continue

        elif re.search("name: B", lines[i]) is not None:
            tb_x = re.sub("\D", "", lines[i].split(" ")[3])
            tb_y = re.sub("\D", "", lines[i].split(" ")[4])
            new_event.update({
                "tb_x": tb_x,
                "tb_y": tb_y
            })
            continue

        elif re.search("name: C", lines[i]) is not None:
            tc_x = re.sub("\D", "", lines[i].split(" ")[3])
            tc_y = re.sub("\D", "", lines[i].split(" ")[4])
            new_event.update({
                "tc_x": tc_x,
                "tc_y": tc_y
            })
            continue

        elif re.search("name: D", lines[i]) is not None:
            td_x = re.sub("\D", "", lines[i].split(" ")[3])
            td_y = re.sub("\D", "", lines[i].split(" ")[4])
            new_event.update({
                "td_x": td_x,
                "td_y": td_y
            })
            continue

        elif re.search("name: E", lines[i]) is not None:
            te_x = re.sub("\D", "", lines[i].split(" ")[3])
            te_y = re.sub("\D", "", lines[i].split(" ")[4])
            new_event.update({
                "te_x": te_x,
                "te_y": te_y
            })
            continue

        elif re.search("name: F", lines[i]) is not None:
            tf_x = re.sub("\D", "", lines[i].split(" ")[3])
            tf_y = re.sub("\D", "", lines[i].split(" ")[4])
            new_event.update({
                "tf_x": tf_x,
                "tf_y": tf_y
            })
            continue
        
        elif re.search("name: G", lines[i]) is not None:
            tg_x = re.sub("\D", "", lines[i].split(" ")[3])
            tg_y = re.sub("\D", "", lines[i].split(" ")[4])
            new_event.update({
                "tg_x": tg_x,
                "tg_y": tg_y
            })
            continue

        
        ## Harzard position
        if re.search("Hazards:", lines[i-1]) is not None:
            new_event.update({
                "h1_x": re.sub("\D", "", lines[i].split(" ")[0]), "h1_y": re.sub("\D", "", lines[i].split(" ")[1]),
                "h2_x": re.sub("\D", "", lines[i].split(" ")[2]), "h2_y": re.sub("\D", "", lines[i].split(" ")[3]),
                "h3_x": re.sub("\D", "", lines[i].split(" ")[4]), "h3_y": re.sub("\D", "", lines[i].split(" ")[5]),
                "h4_x": re.sub("\D", "", lines[i].split(" ")[6]), "h4_y": re.sub("\D", "", lines[i].split(" ")[7]),
                "h5_x": re.sub("\D", "", lines[i].split(" ")[8]), "h5_y": re.sub("\D", "", lines[i].split(" ")[9]),
                "h6_x": re.sub("\D", "", lines[i].split(" ")[10]), "h6_y": re.sub("\D", "", lines[i].split(" ")[11]),
                "h7_x": re.sub("\D", "", lines[i].split(" ")[12]), "h7_y": re.sub("\D", "", lines[i].split(" ")[13]),
                "h8_x": re.sub("\D", "", lines[i].split(" ")[14]), "h8_y": re.sub("\D", "", lines[i].split(" ")[15]),
                "h9_x": re.sub("\D", "", lines[i].split(" ")[16]), "h9_y": re.sub("\D", "", lines[i].split(" ")[17]),
                "h10_x": re.sub("\D", "", lines[i].split(" ")[18]), "h10_y": re.sub("\D", "", lines[i].split(" ")[19])
            })

        ## if the line include "System Log", then create a new event
        if re.search("System Log", lines[i]) is not None:

            if new_event["event_id"] is not None:
                # If new_event not empty and the current line include "System Log", 
                # then append current new_event to event list and create a new new_event

                event_list.append(new_event)
                new_event = dict(zip(keys, [None] * len(keys)))
                event_num += 1

            event_time = lines[i].split(" ")[0] + " " + lines[i].split(" ")[1]

            new_event.update({
                "event_id": event_num, 
                "time": event_time,
                "n_correct": num_correct,
                "n_incorrect": num_incorrect})
# Out:
# 2015-10-21 07:39:55.019    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-21 07:40:02.246    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-10-21 07:40:07.762    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-10-21 07:40:36.158    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-21 07:40:50.658    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-21 07:41:09.459    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-21 07:41:19.6    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-10-21 07:41:24.834    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-10-21 07:41:47.289    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-21 07:42:02.508    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-21 07:42:15.398    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-21 07:42:39.692    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-10-21 07:42:52.785    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-10-21 07:43:05.77    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-21 07:43:13.343    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-21 07:43:21.038    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-21 07:43:35.242    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-21 07:43:55.21    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-21 07:44:08.226    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-10-21 07:44:42.67    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-10-21 07:44:55.955    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-10-21 07:45:02.439    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-10-21 07:45:17.908    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-10-21 07:45:29.441    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-10-21 07:45:45.801    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-21 07:45:59.362    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-21 07:46:31.062    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-10-21 07:46:49.218    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-21 07:47:02.494    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-21 07:47:16.089    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-21 07:47:27.354    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-21 07:47:41.222    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-21 07:47:59.519    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-21 07:48:08.727    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-21 07:48:22.931    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-21 07:48:32.949    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-21 07:48:45.262    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-21 07:49:03.044    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-10-21 07:49:08.935    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-10-21 07:49:15.81    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:02:27.729    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:02:36.995    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:02:45.667    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 06:03:04.9    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:03:10.915    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:03:42.97    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 06:04:04.583    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:04:18.958    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:04:33.565    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:04:46.971    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:05:08.044    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:05:22.672    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:05:41.132    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:05:58.109    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:06:21.84    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:06:37.938    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 06:06:49.422    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 06:07:10.826    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:07:24.915    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:07:45.424    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 06:07:53.002    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:08:07.912    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:08:25.658    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:08:42.93    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:09:00.087    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:09:15.055    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 06:09:30.118    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:09:53.188    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:10:10.086    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:10:32.13    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:10:49.568    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:11:06.907    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:11:18.345    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:11:49.152    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:12:04.52    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 06:09:24.674    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 06:09:36.848    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 06:09:46.613    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 06:09:51.763    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:10:09.504    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 06:10:12.957    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:10:28.051    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 06:10:41.205    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:10:46.565    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:10:53.315    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:11:01.907    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:11:09.609    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:11:40.465    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 06:11:46.512    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:11:53.262    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:12:01.395    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:12:11.395    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 06:12:15.911    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:12:40.438    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 06:12:54.868    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 06:13:00.899    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:13:06.508    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:13:18.149    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:13:21.414    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 06:13:26.039    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:13:43.765    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:13:54.968    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:13:58.765    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:14:03.256    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:14:28.404    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:14:32.06    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 06:14:36.097    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:14:40.847    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:14:58.367    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 06:15:14.062    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 06:15:33.605    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:15:50.147    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:16:00.334    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:16:06.644    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 06:16:39.433    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:16:44.683    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:17:13.956    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:17:36.214    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 06:18:06.743    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:18:43.516    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:18:48.234    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 06:18:52.795    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-10-22 01:45:30.892    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 01:45:43.617    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 01:45:56.663    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 01:46:10.464    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-10-22 01:46:44.341    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 01:46:52.106    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 01:47:12.574    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-10-22 01:47:47.087    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 01:48:02.712    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 01:48:22.738    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 01:48:37.472    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 01:48:57.215    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 01:49:12.243    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 01:49:19.446    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-10-22 01:49:53.697    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 01:50:15.709    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 01:50:27.725    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 01:50:56.273    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 01:51:08.959    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 01:51:38.097    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 01:51:47.097    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 01:51:55.534    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 01:52:13.466    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-10-22 01:52:40.967    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-10-22 01:53:02.967    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 01:53:08.108    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 01:53:28.512    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-10-22 01:53:40.371    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 01:53:54.28    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 01:54:29.67    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-10-22 01:45:03.335    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 01:45:09.82    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-10-22 01:45:24.15    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 01:45:39.572    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 01:46:01.25    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-10-22 01:46:16.11    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 01:46:31.66    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-10-22 01:46:48.552    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 01:47:05.224    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 01:47:38.942    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 01:47:53.786    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 01:48:00.763    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-10-22 01:48:26.236    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-10-22 01:48:43.152    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 01:49:03.449    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 01:49:10.457    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 01:49:19.895    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 01:49:32.863    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 01:49:46.87    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 01:50:11.136    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 01:50:18.076    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 01:50:27.06    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 01:50:56.657    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 01:51:02.899    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-10-22 01:51:10.336    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 01:51:16.179    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 01:51:27.625    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 01:51:38.203    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 01:52:02.637    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-10-22 01:52:12.637    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 01:52:31.038    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-10-22 01:52:44.273    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 01:52:54.64    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 01:53:03.578    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 01:53:12.078    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-10-22 01:53:36.271    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 01:53:42.85    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 01:54:02.594    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-10-22 01:54:09.875    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 01:54:26.832    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 23:17:39.41    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 23:18:11.458    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 23:18:20.756    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 23:18:34.348    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 23:18:45.41    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 23:18:55.335    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 23:19:01.423    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 23:19:08.564    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 23:19:23.144    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 23:19:30.574    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 23:20:10.596    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 23:20:22.783    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 23:20:35.886    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 23:20:51.558    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 23:21:03.764    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 23:21:10.842    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 23:21:31.436    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 23:21:38.188    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 23:21:58.097    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 23:22:04.222    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 23:22:18.88    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 23:22:56.428    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 23:23:07.514    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 23:23:18.773    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 23:23:34.695    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 23:23:44.469    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 23:23:55.688    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 23:24:03.578    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 23:24:09.797    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 23:24:21.319    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 23:24:35.694    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 23:24:41.819    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 23:24:47.994    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 23:25:03.776    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 23:25:15.807    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 23:25:29.09    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 23:25:42.058    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 23:26:08.707    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 23:26:20.16    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 23:26:33.039    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 23:26:40.304    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 23:26:54.195    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:12:15.101    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 06:12:25.038    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:12:39.476    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 06:12:48.678    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 06:13:02.725    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:13:26.177    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:13:40.318    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 06:14:08.815    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 06:14:18.592    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 06:15:01.213    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:15:11.979    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 06:15:20.519    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:15:32.988    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:15:41.723    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:16:15.341    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:16:25.862    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:16:50.561    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:17:05.305    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 06:17:11.43    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 06:17:24.231    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:17:50.762    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:18:00.047    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:18:05.594    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 06:18:10.469    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 06:18:16.711    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 06:18:46.549    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:18:52.457    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:19:11.705    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:19:19.315    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:19:50.298    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:20:08.405    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:20:13.311    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:20:29.793    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 06:20:46.949    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:20:58.474    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 06:21:05.694    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 05:37:33.956    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-10-22 05:37:40.878    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-10-22 05:37:56.005    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 05:38:23.583    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-10-22 05:38:35.295    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-10-22 05:38:46.576    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 05:39:00.738    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-10-22 05:39:24.473    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 05:39:41.774    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 05:39:58.743    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 05:40:20.806    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 05:40:50.275    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 05:41:04.275    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 05:41:12.038    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 05:41:57.892    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 05:42:07.642    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 05:42:27.134    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 05:42:45.099    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 05:42:51.755    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-10-22 05:43:07.88    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 05:43:22.493    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 05:43:28.712    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 05:43:46.682    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-10-22 05:44:05.417    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 05:44:21.635    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 05:44:29.635    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 05:44:42.354    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-10-22 05:45:02.007    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 05:45:20.211    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 05:45:32.846    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 05:45:38.611    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-10-22 05:46:09.62    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-10-22 05:46:14.604    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 05:46:44.197    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 04:10:31.983    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 04:10:42.981    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 04:10:47.8    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 04:11:12.46    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 04:11:41.445    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 04:11:53.415    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 04:12:20.01    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 04:12:36.807    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 04:12:47.854    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 04:12:54.651    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 04:13:22.009    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 04:13:39.64    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 04:13:56.569    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 04:14:10.441    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 04:14:29.064    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 04:14:49.553    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 04:15:00.435    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 04:15:15.975    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 04:15:32.912    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 04:15:48.006    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 04:16:00.358    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 04:16:08.921    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 04:16:23.521    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 04:16:46.69    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 04:17:09.511    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 04:17:27.937    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 04:17:41.156    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 04:17:54.978    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 04:18:01.549    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 04:18:28.191    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 04:18:41.566    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 04:18:47.276    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 04:18:52.23    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 04:19:24.096    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 04:19:35.956    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 04:19:47.491    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-21 05:32:59.256    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-21 05:33:10.209    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-21 05:33:23.74    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-21 05:33:38.101    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-21 05:34:08.194    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-10-21 05:34:20.179    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-21 05:34:36.332    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-21 05:34:47.222    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-21 05:35:12.921    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-10-21 05:35:20.687    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-21 05:35:28.062    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-21 05:35:51.273    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-21 05:36:14.811    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-21 05:36:37.764    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-21 05:36:45.893    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-21 05:37:00.533    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-21 05:37:46.69    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-21 05:38:08.824    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-21 05:38:22.109    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-21 05:38:36.0    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-21 05:38:43.75    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-21 05:39:00.839    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-21 05:39:08.417    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-10-21 05:39:24.081    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-21 05:39:42.238    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-10-21 05:39:48.238    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-21 05:40:31.732    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-21 05:40:40.56    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-21 05:40:46.889    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-21 05:40:54.889    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-21 05:41:06.921    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-10-21 05:41:18.515    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-10-21 05:42:18.152    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 07:58:03.091    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 07:58:15.2    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 07:58:27.511    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 07:58:49.018    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 07:59:17.523    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 07:59:35.521    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 07:59:46.667    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 07:59:57.658    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 08:00:10.498    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 08:00:32.668    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 08:00:39.639    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 08:00:52.211    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 08:01:03.161    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 08:01:48.185    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 08:02:00.674    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 08:02:12.885    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 08:02:21.932    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 08:02:26.804    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 08:02:54.51    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 08:03:08.448    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 08:03:27.075    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 08:03:45.744    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 08:03:55.298    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 08:04:04.264    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 08:04:47.446    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 08:04:56.415    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 08:05:01.496    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 08:05:21.295    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 08:05:28.212    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 08:05:51.877    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 08:06:21.412    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 08:06:32.86    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 08:06:41.454    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 08:07:02.401    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 08:07:09.76    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 08:07:13.776    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 08:07:19.508    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 08:07:25.368    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 07:57:25.868    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 07:57:38.009    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 07:57:51.665    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 07:58:06.413    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 07:58:19.725    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 07:58:31.008    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 07:58:50.535    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 07:59:09.155    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 07:59:24.155    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 07:59:48.227    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 08:00:08.048    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 08:00:22.619    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 08:00:42.758    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 08:00:55.852    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 08:01:04.698    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 08:01:18.17    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 08:01:39.3    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 08:01:54.363    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 08:02:01.993    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 08:02:31.818    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 08:02:51.166    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 08:03:03.158    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 08:03:17.3    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 08:03:29.316    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 08:03:43.994    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 08:03:52.745    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 08:04:07.787    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 08:04:43.538    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 08:04:51.194    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 08:05:05.739    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 08:05:35.385    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 08:05:53.092    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 08:06:11.229    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 08:06:25.321    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 08:06:42.924    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 07:49:20.367    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 07:49:37.367    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 07:49:50.609    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-10-22 07:49:59.875    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 07:50:19.991    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-10-22 07:50:39.022    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 07:50:48.257    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 07:50:55.182    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 07:51:14.448    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 07:51:21.37    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 07:51:35.825    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 07:51:45.903    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 07:51:56.995    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-10-22 07:52:26.977    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-10-22 07:52:55.102    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 07:53:03.019    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 07:53:11.519    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-10-22 07:53:19.855    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 07:53:53.48    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-10-22 07:54:01.793    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 07:54:07.97    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 07:54:23.283    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 07:54:35.33    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 07:54:52.849    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 07:55:00.583    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 07:55:06.099    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 07:55:15.882    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 07:55:25.367    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 07:55:40.397    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 07:55:47.897    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 07:55:54.694    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-10-22 07:56:14.191    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-10-22 07:56:25.402    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 07:56:33.34    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 07:56:40.637    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-10-22 07:57:17.123    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 07:57:30.647    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 07:57:36.6    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 07:57:52.387    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-10-22 07:58:29.483    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 18:14:41.975    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-10-22 18:14:58.726    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 18:15:18.404    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 18:15:38.328    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 18:16:04.729    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-10-22 18:16:15.01    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 18:16:32.197    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 18:16:38.37    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 18:16:59.98    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 18:17:09.137    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 18:17:23.29    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 18:17:50.019    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 18:17:55.925    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 18:18:02.658    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 18:18:19.805    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 18:18:39.007    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 18:18:50.009    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 18:18:57.821    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 18:19:10.225    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 18:19:22.416    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 18:19:40.505    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 18:19:58.821    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 18:20:09.894    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 18:20:29.085    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 18:20:37.152    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 18:20:51.85    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 18:21:14.34    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 18:21:39.713    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 18:21:53.879    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 18:22:08.238    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-10-22 18:22:23.94    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 18:22:31.75    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 18:22:59.345    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 18:23:17.006    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 18:23:36.495    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-10-22 18:23:53.533    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-22 18:24:02.189    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 03:34:37.809    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 03:34:51.168    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 03:35:00.762    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 03:35:12.067    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 03:35:33.849    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 03:35:38.818    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 03:35:54.652    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 03:36:10.386    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 03:36:18.452    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 03:36:28.437    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 03:36:36.781    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 03:37:03.807    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 03:37:14.869    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 03:37:22.016    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 03:37:38.063    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 03:37:45.532    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 03:37:51.232    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 03:38:00.841    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 03:38:18.795    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 03:38:40.946    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 03:38:46.337    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 03:39:13.813    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 03:39:24.298    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 03:39:38.647    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 03:39:49.36    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 03:39:53.188    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 03:40:03.385    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 03:40:09.213    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 03:40:14.417    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 03:40:32.043    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 03:40:41.34    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 03:40:52.699    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 03:40:59.778    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 03:41:20.324    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 03:41:28.746    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 03:41:33.793    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 03:41:44.774    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 03:41:50.602    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 03:42:17.926    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 03:42:33.442    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 03:42:48.332    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 03:43:16.251    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-10-23 03:43:55.396    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-10-23 03:44:00.255    Vehicle: 3 Payload Finished, CORRECT -1,-1

# %% [markdown]
# ### tranform the list to pandas dataframe

# %%
df = pd.DataFrame(event_list)

df.to_csv(csv_file, sep=",")
