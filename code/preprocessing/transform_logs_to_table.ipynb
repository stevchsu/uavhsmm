# %%
import pandas as pd
import numpy as np
import codecs
import re
import os
from datetime import datetime

# %% [markdown]
# ### Goal
# - Transform the system log into dataframe
# - Each row record all activities happened within 1 second
# - User actions include watch (default action), add way point, set goal, apply automation, engage payload
#     - Apply automation is an one-shot action, user apply the system suggestion and the action finished immediately.
#
# - Description of coding
#     - vehicle status
#         - 1: moving
#         - 2: arrived target
#         - 3: engage payload

# %% [markdown]
# ### Set source directory, target file and keys

# %%
root_dir = "/Users/chanhsu/Projects/HRI/uav_hsmm/HMM_Experiment/RAW_DATA/TK/LRC_TK_LW/"
csv_file = "/Users/chanhsu/Projects/HRI/uav_hsmm/uav_hsmm/data/data_20221107/TK/TK_LRC_LW.csv"

keys = (
    "file_name", "event_id", "time", 
    "action", "payload_act", "n_correct", "n_incorrect",
    "v1_x", "v1_y", "v2_x", "v2_y", "v3_x", "v3_y", "v4_x", "v4_y", "v5_x", "v5_y",
    "v1_target", "v2_target", "v3_target", "v4_target", "v5_target",
    "v1_status", "v2_status", "v3_status", "v4_status", "v5_status", 
    "ta_x", "ta_y", "tb_x", "tb_y", "tc_x", "tc_y", "td_x", "td_y", "te_x", "te_y", "tf_x", "tf_y", "tg_x", "tg_y",
    "h1_x", "h1_y", "h2_x", "h2_y", "h3_x", "h3_y", "h4_x", "h4_y", "h5_x", "h5_y", 
    "h6_x", "h6_y", "h7_x", "h7_y", "h8_x", "h8_y", "h9_x", "h9_y", "h10_x", "h10_y",
)
event_list = list()

# %%
os.listdir(root_dir)
# Out:
# ['LRB3_TK_LW.txt_fixed',
#  'LRB16_TK_LW.txt_fixed',
#  'LRB11_TK_LW.txt_fixed',
#  'LRB4_TK_LW.txt_fixed',
#  'LRB5_TK_LW.txt_fixed',
#  'LRB10_TK_LW.txt_fixed',
#  'LRB7_TK_LW.txt_fixed',
#  'LRB12_TK_LW.txt_fixed',
#  'LRB8_TK_LW.txt_fixed',
#  'LRB15_TK_LW.txt_fixed',
#  'desktop.ini',
#  'LRB1_TK_LW.txt_fixed',
#  'LRB14_TK_LW.txt_fixed',
#  'LRB13_TK_LW.txt_fixed',
#  'LRB6_TK_LW.txt_fixed',
#  'LRB21_TK_LW.txt_fixed']

# %% [markdown]
# ### Extract contents from log files

# %%
for file_name in os.listdir(root_dir):
    
    if file_name == "desktop.ini": 
        continue

    ## Initialize values
    event_num = 0
    num_correct = 0
    num_incorrect = 0
    action = None


    ## Load file content
    file_path = root_dir + file_name
    file = codecs.open(file_path, 'r', encoding='utf-8')
    lines  = file.readlines()
    # print(f"""file name: {file_path}""")

    ## remove first line from list (experiment start)
    lines.pop(0)

    new_event = dict(zip(keys, [None] * len(keys)))

    ## Start to transform
    # for i in range(len(lines)):
    for i in range(len(lines)):

        # initialize row
        if i == 0:
            new_event = dict(zip(keys, [None] * len(keys)))
    
        # debug message
        # if i % 10000 == 0:
        #     print(f"""line: {i}, content: {lines[i]}""")

        ## Update action
        if event_num == 0:
            new_event.update({"action": "watch"})
        
        elif re.search('WP add start', lines[i]) is not None:
            new_event.update({"action": "addWP" })
            continue

        elif re.search('WP add end', lines[i]) is not None or re.search('WP add canceled', lines[i]) is not None or re.search('Goal change end', lines[i]) is not None:
            new_event.update({"action": "watch" })
            continue

        elif re.search('Payload Finished', lines[i]) is not None:
            new_event.update({"action": "watch" })
        
        elif re.search('Payload Engaged', lines[i]) is not None:
            new_event.update({"action": "engagePayload" })
            continue
        
        # elif re.search('Payload Finished', lines[i]) is not None:
        #     new_event.update({"action": "watch" })
        #     continue

        elif re.search('Goal set start', lines[i]) is not None:
            new_event.update({"action": "setGoal" })
            continue
        
        # elif re.search('Goal change end', lines[i]) is not None:
        #     new_event.update({"action": "watch" })
        #     continue  
        
        elif re.search('User applies automation', lines[i]) is not None:
            new_event.update({"action": "applyAutomation" })
            continue

        ## Update number of correct and incorrect payload
        if re.search('Payload Finished, INCORRECT', lines[i]) is not None:
            print(lines[i])
            num_incorrect += 1
            
        elif re.search('Payload Finished, CORRECT', lines[i]) is not None:
            print(lines[i])
            num_correct += 1
        
        ## Update payload action: check / hit / safe
        if re.search("User check payload", lines[i]) is not None: 
            new_event.update({
                "payload_act": 0
            })
        elif re.search("User leaves payload by selecting HIT", lines[i]) is not None:
            new_event.update({
                "payload_act": 1
            })
        elif re.search("User leaves payload by selecting SAFE", lines[i]) is not None:
            new_event.update({
                "payload_act": 2
            })
            

        ## Vehicle position, status and target
        if re.search('id: 1', lines[i]) is not None: 
            v1_x = re.sub("\D", "", lines[i].split(" ")[3])
            v1_y = re.sub("\D", "", lines[i].split(" ")[4])

            if len(lines[i].split(" ")) == 11:
                # For status 2 & status 3
                v1_status = re.sub("\D", "", lines[i].split(" ")[8])
                v1_target = lines[i].split(" ")[10]
            elif len(lines[i].split(" ")) >= 13: 
                v1_status = re.sub("\D", "", lines[i].split(" ")[10])
                v1_target = lines[i].split(" ")[12]
            else:
                # For status 1
                v1_status = re.sub("\D", "", lines[i].split(" ")[9])
                v1_target = lines[i].split(" ")[11]

            new_event.update({
                "v1_x": v1_x, 
                "v1_y": v1_y,
                "v1_status": v1_status,
                "v1_target": v1_target})
            continue

        elif re.search('id: 2', lines[i]) is not None: 
            v2_x = re.sub("\D", "", lines[i].split(" ")[3])
            v2_y = re.sub("\D", "", lines[i].split(" ")[4])
            if len(lines[i].split(" ")) <= 11:
                # For status 2 & status 3
                v2_status = re.sub("\D", "", lines[i].split(" ")[8])
                v2_target = lines[i].split(" ")[10]
            elif len(lines[i].split(" ")) >= 13: 
                v2_status = re.sub("\D", "", lines[i].split(" ")[10])
                v2_target = lines[i].split(" ")[12]
            else:
                # For status 1
                v2_status = re.sub("\D", "", lines[i].split(" ")[9])
                v2_target = lines[i].split(" ")[11]

            new_event.update({
                "v2_x": v2_x, 
                "v2_y": v2_y,
                "v2_status": v2_status,
                "v2_target": v2_target})
            continue
                    
        elif re.search('id: 3', lines[i]) is not None: 
            v3_x = re.sub("\D", "", lines[i].split(" ")[3])
            v3_y = re.sub("\D", "", lines[i].split(" ")[4])
            if len(lines[i].split(" ")) <= 11:
                # For status 2 & status 3
                v3_status = re.sub("\D", "", lines[i].split(" ")[8])
                v3_target = lines[i].split(" ")[10]
            elif len(lines[i].split(" ")) >= 13: 
                v3_status = re.sub("\D", "", lines[i].split(" ")[10])
                v3_target = lines[i].split(" ")[12]
            else:
                # For status 1
                v3_status = re.sub("\D", "", lines[i].split(" ")[9])
                v3_target = lines[i].split(" ")[11]

            new_event.update({
                "v3_x": v3_x, 
                "v3_y": v3_y,
                "v3_status": v3_status,
                "v3_target": v3_target})
            continue
                    
        elif re.search('id: 4', lines[i]) is not None: 
            v4_x = re.sub("\D", "", lines[i].split(" ")[3])
            v4_y = re.sub("\D", "", lines[i].split(" ")[4])
            if len(lines[i].split(" ")) <= 11:
                # For status 2 & status 3
                v4_status = re.sub("\D", "", lines[i].split(" ")[8])
                v4_target = lines[i].split(" ")[10]
            elif len(lines[i].split(" ")) >= 13: 
                v4_status = re.sub("\D", "", lines[i].split(" ")[10])
                v4_target = lines[i].split(" ")[12]
            else:
                # For status 1
                v4_status = re.sub("\D", "", lines[i].split(" ")[9])
                v4_target = lines[i].split(" ")[11]

            new_event.update({
                "v4_x": v4_x, 
                "v4_y": v4_y,
                "v4_status": v4_status,
                "v4_target": v4_target})
            continue

        elif re.search('id: 5', lines[i]) is not None: 
            v5_x = re.sub("\D", "", lines[i].split(" ")[3])
            v5_y = re.sub("\D", "", lines[i].split(" ")[4])
            if len(lines[i].split(" ")) <= 11:
                # For status 2 & status 3
                v5_status = re.sub("\D", "", lines[i].split(" ")[8])
                v5_target = lines[i].split(" ")[10]
            elif len(lines[i].split(" ")) >= 13:
                v5_status = re.sub("\D", "", lines[i].split(" ")[10])
                v5_target = lines[i].split(" ")[12]
            else:
                # For status 1
                v5_status = re.sub("\D", "", lines[i].split(" ")[9])
                v5_target = lines[i].split(" ")[11]

            new_event.update({
                "v5_x": v5_x, 
                "v5_y": v5_y,
                "v5_status": v5_status,
                "v5_target": v5_target})
            continue


        ## Target position
        if re.search("name: A", lines[i]) is not None:
            ta_x = re.sub("\D", "", lines[i].split(" ")[3])
            ta_y = re.sub("\D", "", lines[i].split(" ")[4])
            new_event.update({
                "ta_x": ta_x,
                "ta_y": ta_y
            })
            continue

        elif re.search("name: B", lines[i]) is not None:
            tb_x = re.sub("\D", "", lines[i].split(" ")[3])
            tb_y = re.sub("\D", "", lines[i].split(" ")[4])
            new_event.update({
                "tb_x": tb_x,
                "tb_y": tb_y
            })
            continue

        elif re.search("name: C", lines[i]) is not None:
            tc_x = re.sub("\D", "", lines[i].split(" ")[3])
            tc_y = re.sub("\D", "", lines[i].split(" ")[4])
            new_event.update({
                "tc_x": tc_x,
                "tc_y": tc_y
            })
            continue

        elif re.search("name: D", lines[i]) is not None:
            td_x = re.sub("\D", "", lines[i].split(" ")[3])
            td_y = re.sub("\D", "", lines[i].split(" ")[4])
            new_event.update({
                "td_x": td_x,
                "td_y": td_y
            })
            continue

        elif re.search("name: E", lines[i]) is not None:
            te_x = re.sub("\D", "", lines[i].split(" ")[3])
            te_y = re.sub("\D", "", lines[i].split(" ")[4])
            new_event.update({
                "te_x": te_x,
                "te_y": te_y
            })
            continue

        elif re.search("name: F", lines[i]) is not None:
            tf_x = re.sub("\D", "", lines[i].split(" ")[3])
            tf_y = re.sub("\D", "", lines[i].split(" ")[4])
            new_event.update({
                "tf_x": tf_x,
                "tf_y": tf_y
            })
            continue
        
        elif re.search("name: G", lines[i]) is not None:
            tg_x = re.sub("\D", "", lines[i].split(" ")[3])
            tg_y = re.sub("\D", "", lines[i].split(" ")[4])
            new_event.update({
                "tg_x": tg_x,
                "tg_y": tg_y
            })
            continue

        
        ## Harzard position
        if re.search("Hazards:", lines[i-1]) is not None:
            new_event.update({
                "h1_x": re.sub("\D", "", lines[i].split(" ")[0]), "h1_y": re.sub("\D", "", lines[i].split(" ")[1]),
                "h2_x": re.sub("\D", "", lines[i].split(" ")[2]), "h2_y": re.sub("\D", "", lines[i].split(" ")[3]),
                "h3_x": re.sub("\D", "", lines[i].split(" ")[4]), "h3_y": re.sub("\D", "", lines[i].split(" ")[5]),
                "h4_x": re.sub("\D", "", lines[i].split(" ")[6]), "h4_y": re.sub("\D", "", lines[i].split(" ")[7]),
                "h5_x": re.sub("\D", "", lines[i].split(" ")[8]), "h5_y": re.sub("\D", "", lines[i].split(" ")[9]),
                "h6_x": re.sub("\D", "", lines[i].split(" ")[10]), "h6_y": re.sub("\D", "", lines[i].split(" ")[11]),
                "h7_x": re.sub("\D", "", lines[i].split(" ")[12]), "h7_y": re.sub("\D", "", lines[i].split(" ")[13]),
                "h8_x": re.sub("\D", "", lines[i].split(" ")[14]), "h8_y": re.sub("\D", "", lines[i].split(" ")[15]),
                "h9_x": re.sub("\D", "", lines[i].split(" ")[16]), "h9_y": re.sub("\D", "", lines[i].split(" ")[17]),
                "h10_x": re.sub("\D", "", lines[i].split(" ")[18]), "h10_y": re.sub("\D", "", lines[i].split(" ")[19])
            })

        ## if the line include "System Log", then create a new event
        if re.search("System Log", lines[i]) is not None:

            if new_event["event_id"] is not None:
                # If new_event not empty and the current line include "System Log", 
                # then append current new_event to event list and create a new new_event

                event_list.append(new_event)
                new_event = dict(zip(keys, [None] * len(keys)))
                event_num += 1

            event_time = lines[i].split(" ")[0] + " " + lines[i].split(" ")[1]

            new_event.update({
                "file_name": file_name,
                "event_id": event_num, 
                "time": event_time,
                "n_correct": num_correct,
                "n_incorrect": num_incorrect})
# Out:
# 2015-11-19 22:16:33.124    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 22:18:08.536    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 22:18:48.576    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:19:01.022    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:19:20.941    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:19:28.669    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:20:00.849    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:20:14.795    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:20:21.81    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:21:41.511    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:21:51.84    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:22:08.351    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:22:23.314    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:22:52.304    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 22:23:11.227    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:23:52.156    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:24:35.155    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:24:43.288    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:25:33.581    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:25:42.184    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 22:25:58.06    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 22:26:11.708    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 11:52:03.985    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 11:53:52.297    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 11:54:15.871    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 11:54:26.931    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 11:54:48.833    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 11:55:09.644    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 11:55:31.954    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 11:56:05.101    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 11:56:24.9    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 11:56:52.949    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 11:57:12.871    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 11:57:33.434    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 11:57:49.97    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 11:58:33.387    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 11:58:53.981    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 11:59:14.114    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 11:59:32.007    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 12:00:34.094    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 12:00:48.056    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 12:01:03.315    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 12:01:16.466    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 12:01:46.061    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 12:02:03.003    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 17:28:32.284    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 17:30:03.757    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 17:30:29.125    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 17:30:35.235    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 17:31:01.11    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 17:31:08.564    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 17:31:21.928    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 17:31:30.303    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 17:32:38.79    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 17:32:55.832    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 17:33:11.097    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 17:33:43.06    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 17:33:55.174    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 17:34:14.824    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 17:34:33.161    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 17:35:13.613    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 17:36:25.607    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 17:36:32.449    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 17:37:12.137    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 17:37:51.51    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 17:37:58.197    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:15:17.456    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:17:04.279    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:17:34.947    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:17:51.497    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:18:12.364    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:18:34.536    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:18:59.043    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:20:03.755    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:20:57.213    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:21:17.853    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:22:10.44    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:23:03.637    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:23:29.0    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:23:56.595    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:24:16.142    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:16:03.525    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:17:08.688    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 22:17:30.948    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:17:44.152    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:18:34.027    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:18:58.08    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:19:40.952    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:20:09.542    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:20:31.497    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:21:08.842    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:21:35.295    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 22:21:57.528    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:22:21.31    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:22:45.61    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:23:15.38    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:24:08.119    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:24:31.861    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:25:06.306    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 04:28:51.905    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 04:30:17.918    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 04:31:05.646    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 04:31:22.719    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 04:31:47.159    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 04:31:54.805    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 04:32:22.499    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 04:32:39.796    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 04:32:57.694    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 04:33:49.283    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 04:34:05.854    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 04:34:13.183    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 04:34:24.777    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 04:34:38.345    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 04:34:59.064    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 04:35:07.284    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 04:35:49.738    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 04:36:04.691    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 04:36:32.138    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 04:37:04.079    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 04:37:21.161    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 04:38:34.989    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 16:18:36.723    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 16:19:59.101    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 16:20:36.619    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 16:20:46.463    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 16:21:22.721    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 16:21:28.252    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 16:21:55.414    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 16:22:21.828    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 16:22:26.539    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 16:22:54.559    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 16:23:13.049    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 16:23:25.295    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 16:23:47.217    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 16:24:06.332    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 16:24:54.227    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 16:24:57.393    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 16:25:41.424    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 16:25:44.622    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 16:26:15.358    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 16:26:46.843    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 16:26:52.084    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 16:27:18.015    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 16:27:22.883    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 16:27:56.661    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 16:28:06.163    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 16:28:34.76    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 17:28:51.028    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 17:30:27.401    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 17:30:59.153    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 17:31:08.755    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 17:31:33.441    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 17:31:38.591    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 17:31:49.208    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 17:32:04.552    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 17:32:26.591    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 17:32:57.001    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 17:33:55.383    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 17:34:11.164    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 17:34:17.179    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 17:35:04.248    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 17:35:37.52    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 17:35:45.895    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 17:36:13.457    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 17:36:31.119    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 17:36:47.378    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 17:37:23.416    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 17:38:16.236    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:17:29.136    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 22:19:11.545    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:19:19.934    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:19:37.403    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:19:53.229    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:19:56.932    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:20:07.792    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:20:31.772    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:20:35.413    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 22:20:46.845    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:21:10.994    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:21:47.523    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:21:57.253    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:22:15.167    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 22:22:59.046    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:23:02.593    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:23:12.39    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 22:23:29.519    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:24:07.961    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:24:19.418    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:24:23.383    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:24:30.274    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 22:24:40.211    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:25:10.416    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:25:33.477    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:25:38.681    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:26:01.584    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 22:26:36.394    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:26:56.706    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:27:01.155    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:27:05.998    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 22:27:47.915    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 11:56:10.291    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 11:58:04.524    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 11:58:26.803    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 11:58:36.912    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 11:59:05.742    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 11:59:27.74    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 11:59:58.318    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 12:00:14.152    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 12:00:48.178    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 12:01:03.546    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 12:01:47.897    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 12:02:24.705    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 12:02:52.412    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 12:03:02.381    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 12:03:45.517    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 12:03:50.837    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 12:04:10.259    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 12:05:39.809    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 12:05:58.337    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 09:12:09.064    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 09:13:34.449    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 09:13:49.691    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 09:14:10.391    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 09:14:39.233    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 09:14:44.953    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 09:14:58.124    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 09:15:27.379    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 09:15:45.418    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 09:16:03.776    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 09:16:11.245    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 09:16:19.089    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 09:16:41.184    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 09:18:21.403    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 09:18:29.541    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 09:19:01.567    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 09:19:56.071    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 09:20:19.044    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 09:20:30.267    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 09:20:56.593    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 09:21:30.068    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 09:21:37.131    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 09:21:48.007    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 09:21:54.257    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 09:22:03.342    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 11:37:11.043    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 11:38:09.253    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 11:38:31.173    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 11:38:48.756    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 11:39:34.84    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 11:39:47.008    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 11:40:25.283    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 11:40:56.08    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 11:41:11.898    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 11:41:28.624    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 11:41:57.69    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 11:42:12.573    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 11:42:29.797    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 11:42:51.437    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 11:43:30.298    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 11:43:42.841    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 11:44:01.594    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 11:44:18.333    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 11:44:38.038    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 11:45:00.706    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 11:45:09.442    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 11:45:51.986    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 11:46:07.276    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 11:46:33.63    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 11:47:15.596    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 17:29:19.356    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 17:30:49.789    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 17:31:11.928    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 17:31:20.566    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 17:31:50.231    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 17:31:59.715    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 17:32:15.7    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 17:32:30.736    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 17:32:55.459    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 17:33:19.121    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 17:33:35.601    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 17:33:49.668    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 17:34:07.959    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 17:34:35.696    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 17:34:59.513    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 17:35:19.867    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 17:35:38.631    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 17:36:21.254    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 17:36:40.217    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 17:37:03.327    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 17:37:29.685    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 17:38:42.294    Vehicle: 4 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 17:39:01.71    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 16:22:16.517    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 16:23:40.223    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 16:24:25.733    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 16:24:40.199    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 16:24:48.982    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 16:24:55.346    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 16:25:32.342    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 16:26:06.999    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 16:26:15.204    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 16:26:40.31    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 16:26:55.66    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 16:27:28.473    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 16:27:36.058    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 16:27:43.234    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-11-19 16:28:53.823    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 16:28:59.033    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 16:29:32.704    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 16:29:47.247    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 16:29:55.967    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 16:30:53.806    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 16:31:15.025    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 16:31:22.903    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 16:31:29.283    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 16:31:35.539    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-19 16:32:01.313    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 18:01:11.466    Vehicle: 3 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 18:02:38.179    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 18:03:19.289    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 18:03:28.527    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 18:03:43.175    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 18:03:47.871    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 18:04:06.265    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 18:04:52.445    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 18:05:11.524    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 18:05:32.43    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 18:05:45.394    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 18:06:04.287    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 18:06:27.923    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 18:06:51.261    Vehicle: 5 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 18:07:05.647    Vehicle: 2 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 18:07:29.022    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 18:07:50.924    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 18:08:13.696    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 18:08:46.028    Vehicle: 3 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 18:09:05.904    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 18:09:17.667    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 18:09:42.879    Vehicle: 2 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 18:09:51.475    Vehicle: 1 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 18:10:07.186    Vehicle: 5 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 18:10:23.457    Vehicle: 4 Payload Finished, CORRECT -1,-1
#
# 2015-11-20 18:11:02.664    Vehicle: 1 Payload Finished, INCORRECT -1,-1
#
# 2015-11-20 18:11:08.779    Vehicle: 4 Payload Finished, INCORRECT -1,-1

# %% [markdown]
# ### tranform the list to pandas dataframe

# %%
df = pd.DataFrame(event_list)

df.to_csv(csv_file, sep=",")
